# %% [markdown]
# # HashMap / HashSet — Practice Problems
#
# 30 problems organized by difficulty. Each problem has:
# - Problem description and examples
# - TODO stub for you to implement
# - Assert tests to validate your solution
#
# **Difficulty Levels:**
# - Level 1: Warm-up (Problems 1–6)
# - Level 2: Easy Interview (Problems 7–12)
# - Level 3: Medium Core (Problems 13–18)
# - Level 4: Medium+ Interview (Problems 19–24)
# - Level 5: Hard Patterns (Problems 25–30)

# %% [markdown]
# ---
# ## Level 1: Warm-up
# *Pattern: Seen Set, Frequency Map basics*

# %%
# Problem 1: Contains Duplicate
# Given an integer array nums, return True if any value appears at least twice.
# Return False if every element is distinct.
#
# Pattern: Seen Set
# Expected: O(n) time, O(n) space

def contains_duplicate(nums):
    # TODO: your code here
    seen = set()

    for num in nums:
        if num in seen:
            return True
        seen.add(num)
    return False

assert contains_duplicate([1, 2, 3, 1]) == True
assert contains_duplicate([1, 2, 3, 4]) == False
assert contains_duplicate([1, 1, 1, 3, 3, 4, 3, 2, 4, 2]) == True
assert contains_duplicate([]) == False
assert contains_duplicate([1]) == False
print("Problem 1 passed ✓")
# Out:
# Problem 1 passed ✓

# %%
# Problem 2: Valid Anagram
# Given two strings s and t, return True if t is an anagram of s.
# An anagram uses the same characters with the same frequencies.
#
# Pattern: Frequency Map
# Expected: O(n) time, O(1) space (26 letters)

def is_anagram(s, t):
    # TODO: your code here
    if len(s) != len(t):
        return False

    freq = {}

    for ch in s:
        freq[ch] = freq.get(ch, 0) + 1
    
    for ch in t:
        if ch not in freq:
            return False
        freq[ch] -= 1
        if freq[ch] < 0:
            return False
        
    return True

assert is_anagram("anagram", "nagaram") == True
assert is_anagram("rat", "car") == False
assert is_anagram("", "") == True
assert is_anagram("a", "ab") == False
assert is_anagram("aacc", "ccac") == False
print("Problem 2 passed ✓")
# Out:
# Problem 2 passed ✓

# %%
# Problem 3: Two Sum
# Given nums and target, return indices of two numbers that add up to target.
# Assume exactly one solution exists. Don't use the same element twice.
#
# Pattern: Complement Lookup + Index Map
# Expected: O(n) time, O(n) space

def two_sum(nums, target):
    # TODO: your code here
    seen = {}

    for i, num in enumerate(nums):
        diff = target - num
        
        if diff in seen:
            return [seen[diff], i]
        
        seen[num] = i

        

assert two_sum([2, 7, 11, 15], 9) == [0, 1]
assert two_sum([3, 2, 4], 6) == [1, 2]
assert two_sum([3, 3], 6) == [0, 1]
print("Problem 3 passed ✓")
# Out:
# Problem 3 passed ✓

# %%
# Problem 4: First Unique Character in a String
# Given a string s, find the first non-repeating character and return its index.
# If it doesn't exist, return -1.
#
# Pattern: Frequency Map
# Expected: O(n) time, O(1) space (26 letters)

def first_uniq_char(s):
    # TODO: your code here
    freq = {}

    for ch in s:
        freq[ch] = freq.get(ch, 0) + 1
    
    for i, ch in enumerate(s):
        if freq[ch] == 1:
            return i
    return -1


assert first_uniq_char("leetcode") == 0
assert first_uniq_char("loveleetcode") == 2
assert first_uniq_char("aabb") == -1
assert first_uniq_char("") == -1
assert first_uniq_char("a") == 0
print("Problem 4 passed ✓")
# Out:
# Problem 4 passed ✓

# %%
# Problem 5: Intersection of Two Arrays
# Given two integer arrays, return their intersection.
# Each element in the result must be unique.
#
# Pattern: Seen Set
# Expected: O(n + m) time, O(min(n, m)) space

def intersection(nums1, nums2):
    # TODO: your code here (return a list)
    return list(set(nums1) & set(nums2))

assert sorted(intersection([1, 2, 2, 1], [2, 2])) == [2]
assert sorted(intersection([4, 9, 5], [9, 4, 9, 8, 4])) == [4, 9]
assert intersection([1, 2], [3, 4]) == []
print("Problem 5 passed ✓")
# Out:
# Problem 5 passed ✓

# %%
# Problem 6: Jewels and Stones
# jewels is a string of unique characters representing jewel types.
# stones is a string of characters representing stones you have.
# Return how many of your stones are jewels.
#
# Pattern: Seen Set
# Expected: O(n + m) time, O(n) space

def num_jewels_in_stones(jewels, stones):
    # TODO: your code here
    return stones.count(jewels)

assert num_jewels_in_stones("aA", "aAAbbbb") == 3
assert num_jewels_in_stones("z", "ZZ") == 0
assert num_jewels_in_stones("", "abc") == 0
assert num_jewels_in_stones("abc", "") == 0
print("Problem 6 passed ✓")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 13
#       9 def num_jewels_in_stones(jewels, stones):
#      10     # TODO: your code here
#      11     return stones.count(jewels)
#      12
# ---> 13 assert num_jewels_in_stones("aA", "aAAbbbb") == 3
#      14 assert num_jewels_in_stones("z", "ZZ") == 0
#      15 assert num_jewels_in_stones("", "abc") == 0
#      16 assert num_jewels_in_stones("abc", "") == 0
#
# AssertionError:

# %% [markdown]
# ---
# ## Level 2: Easy Interview
# *Pattern: Frequency Map, Group By, Index Map*

# %%
# Problem 7: Intersection of Two Arrays II
# Return intersection INCLUDING duplicates (each element appears as many times
# as it shows in BOTH arrays).
# intersect([1,2,2,1], [2,2]) → [2, 2]
# intersect([4,9,5], [9,4,9,8,4]) → [4, 9]
#
# Pattern: Frequency Map
# Expected: O(n + m) time, O(min(n, m)) space

def intersect(nums1, nums2):
    # TODO: your code here
    count = {}
    result = []

    for num in nums1:
        count[num] = count.get(num, 0) + 1
    
    for num in nums2:
        if num in count and count[num] > 0:
            result.append(num)
            count[num] -= 1
    
    return result

assert sorted(intersect([1,2,2,1], [2,2])) == [2, 2]
assert sorted(intersect([4,9,5], [9,4,9,8,4])) == [4, 9]
assert intersect([1], [2]) == []
print("Problem 7 passed ✓")
# Out:
# Problem 7 passed ✓

# %%
# Problem 8: Group Anagrams
# Given a list of strings, group anagrams together.
# Return list of groups (order doesn't matter).
#
# Pattern: Group By Key
# Expected: O(n * k log k) time

def group_anagrams(strs):
    # TODO: your code here
    group = {}

    for word in strs:
        group[word] = 

result = group_anagrams(["eat", "tea", "tan", "ate", "nat", "bat"])
result_sorted = sorted([sorted(g) for g in result])
assert result_sorted == [['ate', 'eat', 'tea'], ['bat'], ['nat', 'tan']]

assert group_anagrams([""]) == [[""]]
assert group_anagrams(["a"]) == [["a"]]
print("Problem 8 passed ✓")

# %%
# Problem 9: Contains Duplicate II
# Return True if there are two distinct indices i and j such that
# nums[i] == nums[j] and abs(i - j) <= k.
#
# Pattern: Index Map
# Expected: O(n) time, O(min(n, k)) space

def contains_nearby_duplicate(nums, k):
    # TODO: your code here
    pass

assert contains_nearby_duplicate([1,2,3,1], 3) == True
assert contains_nearby_duplicate([1,0,1,1], 1) == True
assert contains_nearby_duplicate([1,2,3,1,2,3], 2) == False
assert contains_nearby_duplicate([], 0) == False
print("Problem 9 passed ✓")

# %%
# Problem 10: Majority Element
# The majority element is the element that appears more than n/2 times.
# You may assume it always exists.
#
# Pattern: Frequency Map (also doable with Boyer-Moore Voting)
# Expected: O(n) time, O(n) space

def majority_element(nums):
    # TODO: your code here
    pass

assert majority_element([3, 2, 3]) == 3
assert majority_element([2, 2, 1, 1, 1, 2, 2]) == 2
assert majority_element([1]) == 1
print("Problem 10 passed ✓")

# %%
# Problem 11: Word Pattern
# Given a pattern and a string s, check if s follows the pattern.
# pattern = "abba", s = "dog cat cat dog" → True
# pattern = "abba", s = "dog cat cat fish" → False
# pattern = "aaaa", s = "dog cat cat dog" → False
#
# Pattern: Two hash maps (bijection)
# Expected: O(n) time, O(n) space

def word_pattern(pattern, s):
    # TODO: your code here
    pass

assert word_pattern("abba", "dog cat cat dog") == True
assert word_pattern("abba", "dog cat cat fish") == False
assert word_pattern("aaaa", "dog cat cat dog") == False
assert word_pattern("abba", "dog dog dog dog") == False
assert word_pattern("abc", "dog cat") == False  # Different lengths
print("Problem 11 passed ✓")

# %%
# Problem 12: Isomorphic Strings
# Two strings are isomorphic if characters in s can be replaced to get t.
# No two characters may map to the same character, and a character may only
# map to itself or one other character.
# "egg" → "add": True  (e→a, g→d)
# "foo" → "bar": False (o→a and o→r)
#
# Pattern: Two hash maps (bijection)
# Expected: O(n) time, O(1) space (bounded alphabet)

def is_isomorphic(s, t):
    # TODO: your code here
    pass

assert is_isomorphic("egg", "add") == True
assert is_isomorphic("foo", "bar") == False
assert is_isomorphic("paper", "title") == True
assert is_isomorphic("badc", "baba") == False
assert is_isomorphic("", "") == True
print("Problem 12 passed ✓")

# %% [markdown]
# ---
# ## Level 3: Medium Core
# *Pattern: Complement, Prefix Sum + HashMap, Consecutive Sequence*

# %%
# Problem 13: Longest Consecutive Sequence
# Given an unsorted array, find the length of the longest consecutive
# elements sequence. MUST run in O(n) time.
#
# Pattern: Seen Set + sequence start detection
# Expected: O(n) time, O(n) space

def longest_consecutive(nums):
    # TODO: your code here
    pass

assert longest_consecutive([100, 4, 200, 1, 3, 2]) == 4
assert longest_consecutive([0, 3, 7, 2, 5, 8, 4, 6, 0, 1]) == 9
assert longest_consecutive([]) == 0
assert longest_consecutive([1]) == 1
assert longest_consecutive([1, 2, 0, 1]) == 3
print("Problem 13 passed ✓")

# %%
# Problem 14: Top K Frequent Elements
# Given nums, return the k most frequent elements. Any order is fine.
#
# Pattern: Frequency Map + bucket sort (or heap)
# Expected: O(n) time with bucket sort

def top_k_frequent(nums, k):
    # TODO: your code here
    pass

assert sorted(top_k_frequent([1,1,1,2,2,3], 2)) == [1, 2]
assert top_k_frequent([1], 1) == [1]
assert sorted(top_k_frequent([4,4,4,1,1,2,2,2,3], 2)) == [2, 4]
print("Problem 14 passed ✓")

# %%
# Problem 15: Subarray Sum Equals K
# Given nums and integer k, return the total number of contiguous subarrays
# whose sum equals k.
#
# Pattern: Prefix Sum + HashMap
# Expected: O(n) time, O(n) space

def subarray_sum(nums, k):
    # TODO: your code here
    pass

assert subarray_sum([1, 1, 1], 2) == 2
assert subarray_sum([1, 2, 3], 3) == 2
assert subarray_sum([1], 0) == 0
assert subarray_sum([0, 0, 0], 0) == 6
assert subarray_sum([-1, -1, 1], 0) == 1
print("Problem 15 passed ✓")

# %%
# Problem 16: Longest Substring Without Repeating Characters
# Given a string, find the length of the longest substring without
# repeating characters.
#
# Pattern: Sliding Window + HashMap
# Expected: O(n) time, O(min(n, alphabet)) space

def length_of_longest_substring(s):
    # TODO: your code here
    pass

assert length_of_longest_substring("abcabcbb") == 3
assert length_of_longest_substring("bbbbb") == 1
assert length_of_longest_substring("pwwkew") == 3
assert length_of_longest_substring("") == 0
assert length_of_longest_substring(" ") == 1
assert length_of_longest_substring("dvdf") == 3
print("Problem 16 passed ✓")

# %%
# Problem 17: Valid Sudoku
# Determine if a 9×9 Sudoku board is valid. Only filled cells need validation.
# Rules: Each row, column, and 3×3 box must contain digits 1-9 without repeats.
# board is a 9x9 list of strings. Empty cells are ".".
#
# Pattern: Seen Set (per row, per col, per box)
# Expected: O(1) time (fixed 81 cells), O(1) space

def is_valid_sudoku(board):
    # TODO: your code here
    pass

valid_board = [
    ["5","3",".",".","7",".",".",".","."],
    ["6",".",".","1","9","5",".",".","."],
    [".","9","8",".",".",".",".","6","."],
    ["8",".",".",".","6",".",".",".","3"],
    ["4",".",".","8",".","3",".",".","1"],
    ["7",".",".",".","2",".",".",".","6"],
    [".","6",".",".",".",".","2","8","."],
    [".",".",".","4","1","9",".",".","5"],
    [".",".",".",".","8",".",".","7","9"]
]
assert is_valid_sudoku(valid_board) == True

invalid_board = [
    ["8","3",".",".","7",".",".",".","."],
    ["6",".",".","1","9","5",".",".","."],
    [".","9","8",".",".",".",".","6","."],
    ["8",".",".",".","6",".",".",".","3"],
    ["4",".",".","8",".","3",".",".","1"],
    ["7",".",".",".","2",".",".",".","6"],
    [".","6",".",".",".",".","2","8","."],
    [".",".",".","4","1","9",".",".","5"],
    [".",".",".",".","8",".",".","7","9"]
]
assert is_valid_sudoku(invalid_board) == False
print("Problem 17 passed ✓")

# %%
# Problem 18: Product of Array Except Self
# Given nums, return an array where result[i] is the product of all
# elements except nums[i]. Do NOT use division.
#
# Pattern: Prefix/Suffix products (not strictly HashMap, but related thinking)
# Expected: O(n) time, O(1) extra space (output doesn't count)

def product_except_self(nums):
    # TODO: your code here
    pass

assert product_except_self([1, 2, 3, 4]) == [24, 12, 8, 6]
assert product_except_self([-1, 1, 0, -3, 3]) == [0, 0, 9, 0, 0]
assert product_except_self([2, 3]) == [3, 2]
print("Problem 18 passed ✓")

# %% [markdown]
# ---
# ## Level 4: Medium+ Interview
# *Pattern: Prefix Sum + HashMap, Sliding Window + HashMap, advanced grouping*

# %%
# Problem 19: Encode and Decode Strings
# Design encode/decode functions for a list of strings.
# Must handle ANY characters including delimiters.
# Hint: Use length-prefix encoding: "5#hello5#world"
#
# Pattern: Encoding (uses string/hash thinking)
# Expected: O(n) time for both

def encode(strs):
    # TODO: your code here
    pass

def decode(s):
    # TODO: your code here
    pass

assert decode(encode(["hello", "world"])) == ["hello", "world"]
assert decode(encode([""])) == [""]
assert decode(encode(["a", "", "b"])) == ["a", "", "b"]
assert decode(encode(["we", "say", ":", "yes"])) == ["we", "say", ":", "yes"]
assert decode(encode([])) == []
print("Problem 19 passed ✓")

# %%
# Problem 20: 4Sum II
# Given four integer arrays, count how many tuples (i, j, k, l) such that
# nums1[i] + nums2[j] + nums3[k] + nums4[l] == 0.
#
# Pattern: Complement Lookup (split into two groups)
# Expected: O(n²) time, O(n²) space

def four_sum_count(nums1, nums2, nums3, nums4):
    # TODO: your code here
    pass

assert four_sum_count([1, 2], [-2, -1], [-1, 2], [0, 2]) == 2
assert four_sum_count([0], [0], [0], [0]) == 1
assert four_sum_count([1], [-1], [0], [0]) == 1
print("Problem 20 passed ✓")

# %%
# Problem 21: Longest Substring with At Most K Distinct Characters
# Given a string s and integer k, find the length of the longest substring
# that contains at most k distinct characters.
#
# Pattern: Sliding Window + HashMap
# Expected: O(n) time, O(k) space

def length_of_longest_substring_k_distinct(s, k):
    # TODO: your code here
    pass

assert length_of_longest_substring_k_distinct("eceba", 2) == 3  # "ece"
assert length_of_longest_substring_k_distinct("aa", 1) == 2
assert length_of_longest_substring_k_distinct("aabacbebebe", 3) == 7  # "cbebebe"
assert length_of_longest_substring_k_distinct("", 2) == 0
assert length_of_longest_substring_k_distinct("a", 0) == 0
print("Problem 21 passed ✓")

# %%
# Problem 22: Contiguous Array (Equal 0s and 1s)
# Given a binary array nums, find the maximum length of a contiguous subarray
# with an equal number of 0 and 1.
# Hint: Replace 0 with -1, then it becomes "subarray sum = 0" problem.
#
# Pattern: Prefix Sum + HashMap
# Expected: O(n) time, O(n) space

def find_max_length(nums):
    # TODO: your code here
    pass

assert find_max_length([0, 1]) == 2
assert find_max_length([0, 1, 0]) == 2
assert find_max_length([0, 0, 1, 0, 0, 0, 1, 1]) == 6
assert find_max_length([0]) == 0
assert find_max_length([0, 1, 1, 0, 1, 1, 1, 0, 0, 0]) == 10
print("Problem 22 passed ✓")

# %%
# Problem 23: Find All Anagrams in a String
# Given strings s and p, return all start indices of p's anagrams in s.
# s = "cbaebabacd", p = "abc" → [0, 6]
#
# Pattern: Sliding Window + Frequency Map
# Expected: O(n) time, O(1) space (26 letters)

def find_anagrams(s, p):
    # TODO: your code here
    pass

assert find_anagrams("cbaebabacd", "abc") == [0, 6]
assert find_anagrams("abab", "ab") == [0, 1, 2]
assert find_anagrams("aaaa", "aa") == [0, 1, 2]
assert find_anagrams("a", "ab") == []
print("Problem 23 passed ✓")

# %%
# Problem 24: Ransom Note
# Given ransomNote and magazine strings, return True if ransomNote can be
# constructed by using the letters from magazine. Each letter can only be used once.
#
# Pattern: Frequency Map
# Expected: O(n + m) time, O(1) space (26 letters)

def can_construct(ransom_note, magazine):
    # TODO: your code here
    pass

assert can_construct("a", "b") == False
assert can_construct("aa", "ab") == False
assert can_construct("aa", "aab") == True
assert can_construct("", "anything") == True
assert can_construct("abc", "cbadba") == True
print("Problem 24 passed ✓")

# %% [markdown]
# ---
# ## Level 5: Hard Patterns
# *Pattern: Complex HashMap combinations, design problems*

# %%
# Problem 25: Minimum Window Substring
# Given strings s and t, return the minimum window substring of s that
# contains every character of t (including duplicates).
# Return "" if no such window exists.
#
# Pattern: Sliding Window + Frequency Map
# Expected: O(n + m) time, O(m) space

def min_window(s, t):
    # TODO: your code here
    pass

assert min_window("ADOBECODEBANC", "ABC") == "BANC"
assert min_window("a", "a") == "a"
assert min_window("a", "aa") == ""
assert min_window("ab", "b") == "b"
print("Problem 25 passed ✓")

# %%
# Problem 26: Continuous Subarray Sum
# Given nums and integer k, return True if nums has a contiguous subarray
# of size at least 2 whose sum is a multiple of k.
#
# Pattern: Prefix Sum + HashMap (remainder theorem)
# Expected: O(n) time, O(min(n, k)) space
# Key insight: if prefix_sum[j] % k == prefix_sum[i] % k, then
# the subarray sum from i+1 to j is divisible by k.

def check_subarray_sum(nums, k):
    # TODO: your code here
    pass

assert check_subarray_sum([23, 2, 4, 6, 7], 6) == True   # [2,4] sum=6
assert check_subarray_sum([23, 2, 6, 4, 7], 6) == True   # [23,2,6,4,7] sum=42
assert check_subarray_sum([23, 2, 6, 4, 7], 13) == False
assert check_subarray_sum([0, 0], 1) == True
assert check_subarray_sum([1], 1) == False  # Length < 2
print("Problem 26 passed ✓")

# %%
# Problem 27: Longest Palindrome
# Given a string s (mixed case), return the length of the longest palindrome
# that can be built with those letters.
# "abccccdd" → 7 ("dccaccd")
#
# Pattern: Frequency Map (count pairs)
# Expected: O(n) time, O(1) space (bounded alphabet)

def longest_palindrome(s):
    # TODO: your code here
    pass

assert longest_palindrome("abccccdd") == 7
assert longest_palindrome("a") == 1
assert longest_palindrome("aaa") == 3
assert longest_palindrome("abcdef") == 1
assert longest_palindrome("Aa") == 1  # Case-sensitive
print("Problem 27 passed ✓")

# %%
# Problem 28: Brick Wall
# There is a rectangular brick wall with several rows of bricks.
# The bricks have the same height, but different widths.
# Draw a vertical line from top to bottom crossing the fewest bricks.
# Return the minimum number of crossed bricks.
# (A line through an edge between bricks doesn't count as crossing.)
#
# Pattern: Frequency Map (count edge positions)
# Key insight: maximize edges at same position = minimize crossings
# Expected: O(n) time where n = total bricks, O(w) space where w = wall width

def least_bricks(wall):
    # TODO: your code here
    pass

assert least_bricks([[1,2,2,1],[3,1,2],[1,3,2],[2,4],[3,1,2],[1,3,1,1]]) == 2
assert least_bricks([[1],[1],[1]]) == 3
assert least_bricks([[1, 1], [1, 1], [1, 1]]) == 0
print("Problem 28 passed ✓")

# %%
# Problem 29: Maximum Number of Balloons
# Given a string text, find the maximum number of times you can spell "balloon"
# using characters from text. Each character can only be used once.
#
# Pattern: Frequency Map
# Expected: O(n) time, O(1) space

def max_number_of_balloons(text):
    # TODO: your code here
    pass

assert max_number_of_balloons("nlaebolko") == 1
assert max_number_of_balloons("loonbalxballpoon") == 2
assert max_number_of_balloons("leetcode") == 0
assert max_number_of_balloons("") == 0
print("Problem 29 passed ✓")

# %%
# Problem 30: Substring with Concatenation of All Words
# Given string s and array of words (all same length), find all starting indices
# of substrings in s that are a concatenation of ALL words in any order.
# s = "barfoothefoobarman", words = ["foo","bar"] → [0, 9]
#
# Pattern: Sliding Window + Frequency Map
# Expected: O(n * word_length) time

def find_substring(s, words):
    # TODO: your code here
    pass

assert sorted(find_substring("barfoothefoobarman", ["foo","bar"])) == [0, 9]
assert find_substring("wordgoodgoodgoodbestword", ["word","good","best","word"]) == []
assert sorted(find_substring("barfoofoobarthefoobarman", ["bar","foo","the"])) == [6, 9, 12]
print("Problem 30 passed ✓")
