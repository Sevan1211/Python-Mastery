# %% [markdown]
# # Two Pointers — Practice Problems
#
# 30 problems across 5 difficulty levels. Each problem has:
# - A function stub (TODO) for you to complete
# - Inline assert tests to verify your solution
# - A success message on pass
#
# **Rules:**
# - Use Two Pointers (no built-in sort tricks unless the problem says sorted input)
# - Write the solution yourself — don't look at the lesson first
# - If stuck for >10 minutes, check the lesson for the pattern template, then try again
#
# ---
# ## Level 1: Warm-Up (Problems 1-6)
# Direct applications of basic two-pointer patterns.

# %%
# Problem 1: Two Sum II - Input Array Is Sorted (LC 167)
# Given a 1-indexed sorted array, find two numbers that add up to target.
# Return their 1-indexed positions [index1, index2].

def two_sum_sorted(numbers, target):
    # TODO
    pass

assert two_sum_sorted([2, 7, 11, 15], 9) == [1, 2]
assert two_sum_sorted([2, 3, 4], 6) == [1, 3]
assert two_sum_sorted([-1, 0], -1) == [1, 2]
assert two_sum_sorted([1, 2, 3, 4, 5], 9) == [4, 5]
print("Problem 1 passed ✓")

# %%
# Problem 2: Valid Palindrome (LC 125)
# Check if a string is a palindrome, considering only alphanumeric characters
# and ignoring case.

def is_palindrome(s):
    # TODO
    pass

assert is_palindrome("A man, a plan, a canal: Panama") == True
assert is_palindrome("race a car") == False
assert is_palindrome(" ") == True
assert is_palindrome("0P") == False
assert is_palindrome("") == True
print("Problem 2 passed ✓")

# %%
# Problem 3: Reverse String (LC 344)
# Reverse a list of characters in-place.
# Do NOT use built-in reverse.

def reverse_string(s):
    # TODO: modify s in-place
    pass

s1 = ["h", "e", "l", "l", "o"]
reverse_string(s1)
assert s1 == ["o", "l", "l", "e", "h"]

s2 = ["H", "a", "n", "n", "a", "h"]
reverse_string(s2)
assert s2 == ["h", "a", "n", "n", "a", "H"]

s3 = ["a"]
reverse_string(s3)
assert s3 == ["a"]
print("Problem 3 passed ✓")

# %%
# Problem 4: Move Zeroes (LC 283)
# Move all 0s to the end while maintaining relative order of non-zero elements.
# Must be in-place.

def move_zeroes(nums):
    # TODO: modify nums in-place
    pass

a = [0, 1, 0, 3, 12]
move_zeroes(a)
assert a == [1, 3, 12, 0, 0]

b = [0]
move_zeroes(b)
assert b == [0]

c = [1, 2, 3]
move_zeroes(c)
assert c == [1, 2, 3]

d = [0, 0, 0, 1]
move_zeroes(d)
assert d == [1, 0, 0, 0]
print("Problem 4 passed ✓")

# %%
# Problem 5: Remove Element (LC 27)
# Remove all occurrences of val in-place. Return the new length.
# Elements beyond the new length don't matter.

def remove_element(nums, val):
    # TODO: return new length
    pass

a = [3, 2, 2, 3]
k = remove_element(a, 3)
assert k == 2
assert sorted(a[:k]) == [2, 2]

b = [0, 1, 2, 2, 3, 0, 4, 2]
k = remove_element(b, 2)
assert k == 5
assert sorted(b[:k]) == [0, 0, 1, 3, 4]

c = []
assert remove_element(c, 1) == 0
print("Problem 5 passed ✓")

# %%
# Problem 6: Merge Sorted Array (LC 88)
# Merge nums2 into nums1 in-place. nums1 has enough space (m + n length).
# nums1[:m] and nums2 are sorted.

def merge(nums1, m, nums2, n):
    # TODO: merge in-place, fill from the back
    pass

a = [1, 2, 3, 0, 0, 0]
merge(a, 3, [2, 5, 6], 3)
assert a == [1, 2, 2, 3, 5, 6]

b = [1]
merge(b, 1, [], 0)
assert b == [1]

c = [0]
merge(c, 0, [1], 1)
assert c == [1]
print("Problem 6 passed ✓")

# %% [markdown]
# ---
# ## Level 2: Easy Interview (Problems 7-12)
# Slightly more involved but still basic pattern applications.

# %%
# Problem 7: Remove Duplicates from Sorted Array (LC 26)
# Remove duplicates in-place from a sorted array.
# Return the number of unique elements.

def remove_duplicates(nums):
    # TODO
    pass

a = [1, 1, 2]
k = remove_duplicates(a)
assert k == 2
assert a[:k] == [1, 2]

b = [0, 0, 1, 1, 1, 2, 2, 3, 3, 4]
k = remove_duplicates(b)
assert k == 5
assert b[:k] == [0, 1, 2, 3, 4]

c = [1]
assert remove_duplicates(c) == 1
print("Problem 7 passed ✓")

# %%
# Problem 8: Is Subsequence (LC 392)
# Check if s is a subsequence of t.

def is_subsequence(s, t):
    # TODO
    pass

assert is_subsequence("abc", "ahbgdc") == True
assert is_subsequence("axc", "ahbgdc") == False
assert is_subsequence("", "anything") == True
assert is_subsequence("a", "") == False
assert is_subsequence("", "") == True
print("Problem 8 passed ✓")

# %%
# Problem 9: Squares of a Sorted Array (LC 977)
# Given a sorted array (may have negatives), return squares in sorted order.
# Must be O(n) — don't just square and sort.

def sorted_squares(nums):
    # TODO
    pass

assert sorted_squares([-4, -1, 0, 3, 10]) == [0, 1, 9, 16, 100]
assert sorted_squares([-7, -3, 2, 3, 11]) == [4, 9, 9, 49, 121]
assert sorted_squares([0]) == [0]
assert sorted_squares([-5, -3, -1]) == [1, 9, 25]
print("Problem 9 passed ✓")

# %%
# Problem 10: Reverse Vowels of a String (LC 345)
# Reverse only the vowels in a string.
# Vowels: a, e, i, o, u (upper and lowercase).

def reverse_vowels(s):
    # TODO
    pass

assert reverse_vowels("hello") == "holle"
assert reverse_vowels("leetcode") == "leotcede"
assert reverse_vowels("aA") == "Aa"
assert reverse_vowels("xyz") == "xyz"
print("Problem 10 passed ✓")

# %%
# Problem 11: Valid Palindrome II (LC 680)
# Can a string become a palindrome by removing at most one character?

def valid_palindrome(s):
    # TODO
    pass

assert valid_palindrome("aba") == True
assert valid_palindrome("abca") == True
assert valid_palindrome("abc") == False
assert valid_palindrome("a") == True
assert valid_palindrome("deeee") == True
print("Problem 11 passed ✓")

# %%
# Problem 12: Remove Duplicates from Sorted Array II (LC 80)
# Remove duplicates in-place so each element appears at most TWICE.
# Return the new length.

def remove_duplicates_ii(nums):
    # TODO
    pass

a = [1, 1, 1, 2, 2, 3]
k = remove_duplicates_ii(a)
assert k == 5
assert a[:k] == [1, 1, 2, 2, 3]

b = [0, 0, 1, 1, 1, 1, 2, 3, 3]
k = remove_duplicates_ii(b)
assert k == 7
assert b[:k] == [0, 0, 1, 1, 2, 3, 3]
print("Problem 12 passed ✓")

# %% [markdown]
# ---
# ## Level 3: Medium Core (Problems 13-18)
# Classic interview problems requiring confident two-pointer usage.

# %%
# Problem 13: 3Sum (LC 15)
# Find all unique triplets that sum to 0.
# Handle duplicates correctly!

def three_sum(nums):
    # TODO
    pass

result = three_sum([-1, 0, 1, 2, -1, -4])
assert sorted([sorted(t) for t in result]) == [[-1, -1, 2], [-1, 0, 1]]

assert three_sum([0, 1, 1]) == []
assert three_sum([0, 0, 0]) == [[0, 0, 0]]
assert three_sum([]) == []
print("Problem 13 passed ✓")

# %%
# Problem 14: Container With Most Water (LC 11)
# Given heights, find two lines that form a container with most water.

def max_area(height):
    # TODO
    pass

assert max_area([1, 8, 6, 2, 5, 4, 8, 3, 7]) == 49
assert max_area([1, 1]) == 1
assert max_area([4, 3, 2, 1, 4]) == 16
assert max_area([1, 2, 1]) == 2
print("Problem 14 passed ✓")

# %%
# Problem 15: Sort Colors (LC 75)
# Sort an array of 0s, 1s, and 2s in-place.
# One-pass solution (Dutch National Flag).

def sort_colors(nums):
    # TODO: modify in-place
    pass

a = [2, 0, 2, 1, 1, 0]
sort_colors(a)
assert a == [0, 0, 1, 1, 2, 2]

b = [2, 0, 1]
sort_colors(b)
assert b == [0, 1, 2]

c = [0]
sort_colors(c)
assert c == [0]

d = [2, 2, 2, 0, 0, 0]
sort_colors(d)
assert d == [0, 0, 0, 2, 2, 2]
print("Problem 15 passed ✓")

# %%
# Problem 16: 3Sum Closest (LC 16)
# Find the triplet sum closest to target. Return the sum.

def three_sum_closest(nums, target):
    # TODO
    pass

assert three_sum_closest([-1, 2, 1, -4], 1) == 2
assert three_sum_closest([0, 0, 0], 1) == 0
assert three_sum_closest([1, 1, 1, 0], -100) == 2
print("Problem 16 passed ✓")

# %%
# Problem 17: String Compression (LC 443)
# Compress in-place: ["a","a","b","b","c","c","c"] → ["a","2","b","2","c","3"]
# If count is 1, don't add the number.
# Return the new length.

def compress(chars):
    # TODO: modify chars in-place, return new length
    pass

a = ["a", "a", "b", "b", "c", "c", "c"]
k = compress(a)
assert k == 6
assert a[:k] == ["a", "2", "b", "2", "c", "3"]

b = ["a"]
k = compress(b)
assert k == 1
assert b[:k] == ["a"]

c = ["a", "b", "b", "b", "b", "b", "b", "b", "b", "b", "b", "b", "b"]
k = compress(c)
assert k == 4
assert c[:k] == ["a", "b", "1", "2"]
print("Problem 17 passed ✓")

# %%
# Problem 18: Rotate Array (LC 189)
# Rotate array to the right by k steps.
# Do it in-place with O(1) extra space.
# Hint: three reverses — reverse all, reverse first k, reverse rest.

def rotate(nums, k):
    # TODO: modify in-place
    pass

a = [1, 2, 3, 4, 5, 6, 7]
rotate(a, 3)
assert a == [5, 6, 7, 1, 2, 3, 4]

b = [-1, -100, 3, 99]
rotate(b, 2)
assert b == [3, 99, -1, -100]

c = [1, 2]
rotate(c, 3)  # k > len, should wrap
assert c == [2, 1]
print("Problem 18 passed ✓")

# %% [markdown]
# ---
# ## Level 4: Medium+ (Problems 19-24)
# Trickier variations and combinations.

# %%
# Problem 19: 4Sum (LC 18)
# Find all unique quadruplets that sum to target.
# Hint: fix two elements, two-pointer on the rest.

def four_sum(nums, target):
    # TODO
    pass

result = four_sum([1, 0, -1, 0, -2, 2], 0)
expected = [[-2, -1, 1, 2], [-2, 0, 0, 2], [-1, 0, 0, 1]]
assert sorted([sorted(q) for q in result]) == expected

assert four_sum([2, 2, 2, 2, 2], 8) == [[2, 2, 2, 2]]
print("Problem 19 passed ✓")

# %%
# Problem 20: Trapping Rain Water (LC 42)
# Calculate trapped rainwater using two pointers.
# O(n) time, O(1) space.

def trap(height):
    # TODO
    pass

assert trap([0, 1, 0, 2, 1, 0, 1, 3, 2, 1, 2, 1]) == 6
assert trap([4, 2, 0, 3, 2, 5]) == 9
assert trap([]) == 0
assert trap([3]) == 0
assert trap([3, 0, 3]) == 3
print("Problem 20 passed ✓")

# %%
# Problem 21: Boats to Save People (LC 881)
# Each boat carries at most 2 people with a weight limit.
# Given people's weights (sorted), find min boats needed.
#
# Greedy + Two Pointers: pair heaviest with lightest if they fit.

def num_rescue_boats(people, limit):
    # TODO
    pass

assert num_rescue_boats([1, 2], 3) == 1
assert num_rescue_boats([3, 2, 2, 1], 3) == 3
assert num_rescue_boats([3, 5, 3, 4], 5) == 4
assert num_rescue_boats([1, 1, 1, 1], 3) == 2
print("Problem 21 passed ✓")

# %%
# Problem 22: Next Permutation (LC 31)
# Rearrange numbers into the next lexicographically greater permutation.
# If it's the last permutation, rearrange to the first (ascending).
#
# Steps: 1) Find rightmost ascent (i where nums[i] < nums[i+1])
#        2) Find rightmost element > nums[i], swap
#        3) Reverse suffix after i

def next_permutation(nums):
    # TODO: modify in-place
    pass

a = [1, 2, 3]
next_permutation(a)
assert a == [1, 3, 2]

b = [3, 2, 1]
next_permutation(b)
assert b == [1, 2, 3]

c = [1, 1, 5]
next_permutation(c)
assert c == [1, 5, 1]

d = [1, 3, 2]
next_permutation(d)
assert d == [2, 1, 3]
print("Problem 22 passed ✓")

# %%
# Problem 23: Partition Labels (LC 763)
# Partition string so each letter appears in at most one part.
# Return sizes of the parts.
#
# Hint: Precompute last occurrence, then use two pointers to find partitions.

def partition_labels(s):
    # TODO
    pass

assert partition_labels("ababcbacadefegdehijhklij") == [9, 7, 8]
assert partition_labels("eccbbbbdec") == [10]
assert partition_labels("a") == [1]
print("Problem 23 passed ✓")

# %%
# Problem 24: Sort Array By Parity (LC 905)
# Rearrange so even numbers come first, then odd.
# In-place, O(1) space.

def sort_by_parity(nums):
    # TODO: modify in-place, return nums
    pass

a = [3, 1, 2, 4]
result = sort_by_parity(a)
# Check: all evens before all odds
split = 0
while split < len(result) and result[split] % 2 == 0:
    split += 1
assert all(x % 2 == 0 for x in result[:split])
assert all(x % 2 == 1 for x in result[split:])

b = [0]
sort_by_parity(b)
assert b == [0]
print("Problem 24 passed ✓")

# %% [markdown]
# ---
# ## Level 5: Hard / Advanced (Problems 25-30)
# Complex problems requiring mastery of Two Pointers.

# %%
# Problem 25: Trapping Rain Water II — 1D variant challenge
# Same as Trapping Rain Water (LC 42) but implement it BOTH ways:
# a) Two pointer approach (O(1) space)
# b) Prefix/suffix max array approach (O(n) space)
# Both must return the same answer.

def trap_two_pointer(height):
    # TODO: O(1) space
    pass

def trap_prefix(height):
    # TODO: O(n) space
    pass

test_cases = [
    [0, 1, 0, 2, 1, 0, 1, 3, 2, 1, 2, 1],
    [4, 2, 0, 3, 2, 5],
    [3, 0, 3],
    [],
    [1, 2, 3, 4, 5],
]
expected = [6, 9, 3, 0, 0]

for h, exp in zip(test_cases, expected):
    a = trap_two_pointer(h)
    b = trap_prefix(h)
    assert a == exp, f"two_pointer({h}) = {a}, expected {exp}"
    assert b == exp, f"prefix({h}) = {b}, expected {exp}"
    assert a == b, f"Mismatch: two_pointer={a}, prefix={b}"
print("Problem 25 passed ✓")

# %%
# Problem 26: 3Sum Smaller (LC 259)
# Given a sorted array and target, count triplets with sum < target.
#
# Key insight: when nums[i] + nums[left] + nums[right] < target,
# ALL pairs (left, left+1, ..., right) with i work. So count += right - left.

def three_sum_smaller(nums, target):
    # TODO
    pass

assert three_sum_smaller([-2, 0, 1, 3], 2) == 2  # (-2,0,1), (-2,0,3)
assert three_sum_smaller([], 0) == 0
assert three_sum_smaller([0], 0) == 0
assert three_sum_smaller([1, 1, 1, 1], 4) == 4
print("Problem 26 passed ✓")

# %%
# Problem 27: Reverse Words in a String (LC 151)
# Given a string with words separated by spaces, reverse the word order.
# Trim leading/trailing spaces and reduce multiple spaces to one.
#
# Challenge: Do it using two-pointer reversal (reverse all, then reverse each word).
# Since Python strings are immutable, work with a list of chars.

def reverse_words(s):
    # TODO
    pass

assert reverse_words("the sky is blue") == "blue is sky the"
assert reverse_words("  hello world  ") == "world hello"
assert reverse_words("a good   example") == "example good a"
print("Problem 27 passed ✓")

# %%
# Problem 28: Two Sum Less Than K (LC 1099)
# Find the pair sum closest to K but strictly less than K.
# Return -1 if no valid pair exists.

def two_sum_less_than_k(nums, k):
    # TODO
    pass

assert two_sum_less_than_k([34, 23, 1, 24, 75, 33, 54, 8], 60) == 58
assert two_sum_less_than_k([10, 20, 30], 15) == -1
assert two_sum_less_than_k([1, 1], 2) == -1
assert two_sum_less_than_k([254, 914, 110, 900, 147, 441, 209, 122, 571, 942, 136], 1000) == 996
print("Problem 28 passed ✓")

# %%
# Problem 29: Interval List Intersections (LC 986)
# Given two lists of closed intervals (sorted by start), return their intersections.
# Each list is pairwise disjoint and sorted.
#
# Two pointers: one per list. Advance the one that ends first.

def interval_intersection(first_list, second_list):
    # TODO
    pass

assert interval_intersection(
    [[0,2],[5,10],[13,23],[24,25]],
    [[1,5],[8,12],[15,24],[25,26]]
) == [[1,2],[5,5],[8,10],[15,23],[24,24],[25,25]]

assert interval_intersection([[1,3],[5,9]], []) == []
assert interval_intersection([], [[4,8],[10,12]]) == []
assert interval_intersection([[1,7]], [[3,10]]) == [[3,7]]
print("Problem 29 passed ✓")

# %%
# Problem 30: Longest Mountain in Array (LC 845)
# Find the length of the longest mountain subarray.
# A mountain has: strictly increasing then strictly decreasing, length >= 3.
#
# Use two pointers to scan for peaks and expand left/right.

def longest_mountain(arr):
    # TODO
    pass

assert longest_mountain([2, 1, 4, 7, 3, 2, 5]) == 5  # [1,4,7,3,2]
assert longest_mountain([2, 2, 2]) == 0
assert longest_mountain([0, 1, 2, 3, 4, 5, 4, 3, 2, 1, 0]) == 11
assert longest_mountain([]) == 0
assert longest_mountain([1, 2]) == 0
assert longest_mountain([0, 2, 0]) == 3
print("Problem 30 passed ✓")
