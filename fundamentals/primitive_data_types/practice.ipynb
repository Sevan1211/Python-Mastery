# %% [markdown]
# # Primitive Data Types — Practice Drills
#
# Solve each drill, then run the cell. Tests at the bottom of each cell will tell you if you got it right.
#
# **Rules:**
# - Don't look at the asserts before writing your solution
# - If a test fails, read the error message and fix your code
# - Move on only when all tests pass with ✓
#
# ---
#
# ## Level 1: Type Identification

# %%
# Drill 1: What type is each value? Return a list of type name strings.
# Example: [42, 3.14] → ["int", "float"]

def drill_identify_types():
    """Return a list of type names for each value."""
    values = [42, 3.14, "hello", True, None, 0, "", 1.0, False]
    # TODO: return a list like ["int", "float", ...] for each value above
    results = []
    for v in values:
        results.append(type(v).__name__)
    
    return results

# --- Tests ---
result = drill_identify_types()
expected = ["int", "float", "str", "bool", "NoneType", "int", "str", "float", "bool"]
assert result == expected, f"Expected {expected}, got {result}"
print("Drill 1 passed ✓")
# Out:
# Drill 1 passed ✓

# %%
# Drill 2: What type does each expression produce?
# Return a list of type name strings.

def drill_type_of_expression():
    """Return the type name of each expression result."""
    a = 10 / 2      # what type?
    b = 10 // 2     # what type?
    c = True + 1    # what type?
    d = str(42)     # what type?
    e = float(5)    # what type?
    # TODO: Return a list of type name strings like ["float", "int", ...]
    types = []

    
    pass

# --- Tests ---
result = drill_type_of_expression()
expected = ["float", "int", "int", "str", "float"]
assert result == expected, f"Expected {expected}, got {result}"
print("Drill 2 passed ✓")

# %% [markdown]
# ## Level 2: Type Conversion

# %%
# Drill 3: Convert between types.
# Fill in each variable with the correct conversion.

def drill_conversions():
    """Perform the requested conversions and return results as a tuple."""
    # Convert "123" to an integer
    a = None  # TODO

    # Convert 3.75 to an integer (what happens to the decimal?)
    b = None  # TODO

    # Convert 0 to a boolean
    c = None  # TODO

    # Convert True to an integer
    d = None  # TODO

    # Convert 42 to a string
    e = None  # TODO

    return (a, b, c, d, e)

# --- Tests ---
a, b, c, d, e = drill_conversions()
assert a == 123 and isinstance(a, int), f"a: expected int 123, got {a}"
assert b == 3 and isinstance(b, int), f"b: expected int 3, got {b}"
assert c is False, f"c: expected False, got {c}"
assert d == 1 and isinstance(d, int), f"d: expected int 1, got {d}"
assert e == "42" and isinstance(e, str), f"e: expected str '42', got {e}"
print("Drill 3 passed ✓")

# %%
# Drill 4: Fix the broken conversion.
# Given a string like "10.5", convert it to an int.
# Hint: you can't go directly from "10.5" → int.

def drill_fix_conversion(value_str):
    """Convert a string representing a decimal number to an int."""
    # TODO: return the integer part of the string number
    pass

# --- Tests ---
assert drill_fix_conversion("10.5") == 10, f"Expected 10, got {drill_fix_conversion('10.5')}"
assert drill_fix_conversion("7.0") == 7, f"Expected 7, got {drill_fix_conversion('7.0')}"
assert drill_fix_conversion("-3.9") == -3, f"Expected -3, got {drill_fix_conversion('-3.9')}"
print("Drill 4 passed ✓")

# %% [markdown]
# ## Level 3: Truthy / Falsy

# %%
# Drill 5: Predict truthy or falsy.
# Return a list of booleans — True if the value is truthy, False if falsy.
# Write out the list manually (don't use a loop or comprehension).

def drill_truthy_falsy():
    """Return a list of booleans for each value's truthiness."""
    values = [0, 1, -1, "", "0", None, True, False, 0.0, 3.14]
    # TODO: return a list like [False, True, ...]
    pass

# --- Tests ---
result = drill_truthy_falsy()
expected = [False, True, True, False, True, False, True, False, False, True]
assert result == expected, f"Expected {expected}, got {result}"
print("Drill 5 passed ✓")

# %%
# Drill 6: Safe default with truthy check.
# Return "Hello, {name}!" if name is truthy.
# Return "Hello, stranger!" if name is falsy (empty string, None, etc).

def drill_safe_greeting(name):
    # TODO
    pass

# --- Tests ---
assert drill_safe_greeting("Sevan") == "Hello, Sevan!", f"Got {drill_safe_greeting('Sevan')}"
assert drill_safe_greeting("") == "Hello, stranger!", f"Got {drill_safe_greeting('')}"
assert drill_safe_greeting(None) == "Hello, stranger!", f"Got {drill_safe_greeting(None)}"
print("Drill 6 passed ✓")

# %% [markdown]
# ## Level 4: Operators and Edge Cases

# %%
# Drill 7: Division trio.
# Return a tuple of (true_division, floor_division, remainder).
# Example: drill_division(10, 3) → (3.333..., 3, 1)

def drill_division(a, b):
    # TODO
    pass

# --- Tests ---
r = drill_division(10, 3)
assert abs(r[0] - 3.3333333333333335) < 1e-9, f"true div: got {r[0]}"
assert r[1] == 3, f"floor div: expected 3, got {r[1]}"
assert r[2] == 1, f"remainder: expected 1, got {r[2]}"

r2 = drill_division(10, 2)
assert r2 == (5.0, 5, 0), f"Expected (5.0, 5, 0), got {r2}"

r3 = drill_division(-7, 2)
assert r3[0] == -3.5, f"true div: expected -3.5, got {r3[0]}"
assert r3[1] == -4, f"floor div: expected -4 (rounds toward -∞), got {r3[1]}"
assert r3[2] == 1, f"remainder: expected 1, got {r3[2]}"
print("Drill 7 passed ✓")

# %%
# Drill 8: Float precision trap.
# Return a tuple: (naive_check, smart_check)
# naive_check: does 0.1 + 0.2 == 0.3 ?
# smart_check: use abs() to check if the difference is < 1e-9

def drill_float_check():
    naive_check = None   # TODO
    smart_check = None   # TODO
    return (naive_check, smart_check)

# --- Tests ---
naive, smart = drill_float_check()
assert naive is False, f"naive should be False, got {naive}"
assert smart is True, f"smart should be True, got {smart}"
print("Drill 8 passed ✓")

# %%
# Drill 9: None check.
# Return "empty" if value is None, otherwise return the value itself.
# Use the correct Python idiom (is, not ==).

def drill_none_check(value):
    # TODO
    pass

# --- Tests ---
assert drill_none_check(None) == "empty", f"Got {drill_none_check(None)}"
assert drill_none_check(42) == 42, f"Got {drill_none_check(42)}"
assert drill_none_check(0) == 0, f"0 is not None! Got {drill_none_check(0)}"
assert drill_none_check("") == "", f"Empty string is not None! Got {drill_none_check('')}"
print("Drill 9 passed ✓")

# %% [markdown]
# ## Level 5: Debugging

# %%
# Drill 10: Find and fix ALL the bugs.
# This function should return (15, "count: 5", True).

def drill_debug_types():
    # Bug 1: This should produce the integer 15
    x = "10" + 5

    # Bug 2: This should produce the string "count: 5"
    count = 5
    message = "count: " + count

    # Bug 3: This should be True, using the Pythonic idiom
    result = None == None

    return (x, message, result)

# --- Tests ---
x, message, result = drill_debug_types()
assert x == 15, f"Bug 1 not fixed: got {x}"
assert message == "count: 5", f"Bug 2 not fixed: got {message}"
assert result is True, f"Bug 3 not fixed: got {result}"
print("Drill 10 passed ✓")

# %% [markdown]
# ---
#
# ## All Done!
#
# If every cell above shows ✓, you've completed the practice drills. Next steps:
# 1. Review `cheatsheet.md` for quick reference
# 2. Quiz yourself with `review.md` prompts
# 3. Move on to the next module when ready
