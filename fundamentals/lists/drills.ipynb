# %% [markdown]
# # Lists — Drills (Interactive)
#
# **28+ interactive exercises** covering:
#
# | Section | Type | Count |
# |---------|------|-------|
# | A | Predict the Output | 8 |
# | B | Fill in the Blank | 5 |
# | C | Debug the Bug | 6 |
# | D | Build from Scratch | 6 |
# | E | Explore & Discover | 5 |
#
# **Instructions:** Read the code, make your prediction, then run the cell to check.

# %% [markdown]
# ---
# ## Section A: Predict the Output
#
# Read the code carefully and predict what will be printed. Then run the cell to check.

# %%
# A1: What does this print?
# YOUR PREDICTION: ???

nums = [10, 20, 30, 40, 50]
print(nums[1:4])
print(nums[-2:])
print(nums[::2])

# %%
# A2: What does this print?
# YOUR PREDICTION: ???

a = [1, 2, 3]
b = a
b.append(4)
print(a)
print(a is b)

# %%
# A3: What does this print?
# YOUR PREDICTION: ???

x = [1, 2, 3]
y = x[:]
y.append(4)
print(x)
print(y)
print(x is y)

# %%
# A4: What does this print?
# YOUR PREDICTION: ???

nums = [5, 3, 1, 4, 2]
result = nums.sort()
print(result)
print(nums)

# %%
# A5: What does this print?
# YOUR PREDICTION: ???

lst = [1, 2, 3]
lst.append([4, 5])
print(len(lst))
print(lst)

# %%
# A6: What does this print?
# YOUR PREDICTION: ???

lst = [1, 2, 3]
lst.extend([4, 5])
print(len(lst))
print(lst)

# %%
# A7: What does this print?
# YOUR PREDICTION: ???

grid = [[0] * 3] * 2
grid[0][1] = 5
print(grid)

# %%
# A8: What does this print?
# YOUR PREDICTION: ???

items = ["a", "b", "c", "d"]
popped = items.pop(1)
print(popped)
print(items)
items.insert(1, "x")
print(items)

# %% [markdown]
# ---
# ## Section B: Fill in the Blank
#
# Replace `____` with the correct code to make the assertions pass.

# %%
# B1: Get the last 3 elements of a list
nums = [10, 20, 30, 40, 50]
last_three = nums[____]

assert last_three == [30, 40, 50]
print("B1 passed ✓")

# %%
# B2: Reverse a list WITHOUT mutating the original
original = [1, 2, 3, 4, 5]
reversed_copy = ____

assert reversed_copy == [5, 4, 3, 2, 1]
assert original == [1, 2, 3, 4, 5]  # original unchanged
print("B2 passed ✓")

# %%
# B3: Sort a list of strings by their length (shortest first)
words = ["banana", "apple", "fig", "cherry", "date"]
by_length = sorted(words, ____)

assert by_length == ["fig", "date", "apple", "banana", "cherry"]
print("B3 passed ✓")

# %%
# B4: Create a list of tuples pairing names with scores
names = ["Alice", "Bob", "Charlie"]
scores = [90, 85, 92]
pairs = list(____(names, scores))

assert pairs == [("Alice", 90), ("Bob", 85), ("Charlie", 92)]
print("B4 passed ✓")

# %%
# B5: Use unpacking to get the first element and the rest
data = [10, 20, 30, 40, 50]
____, ____rest = data

assert first == 10
assert rest == [20, 30, 40, 50]
print("B5 passed ✓")

# %% [markdown]
# ---
# ## Section C: Debug the Bug
#
# Each cell has a bug. Find it, fix it, and make the assertions pass.

# %%
# C1: This should return a sorted version of the list, but something's wrong.

nums = [5, 3, 1, 4, 2]
sorted_nums = nums.sort()  # Bug is here

# Fix it so sorted_nums contains [1, 2, 3, 4, 5] and nums is unchanged
assert sorted_nums == [1, 2, 3, 4, 5]
assert nums == [5, 3, 1, 4, 2]  # original unchanged
print("C1 passed ✓")

# %%
# C2: This should add [4, 5] as individual elements, not nested.

items = [1, 2, 3]
items.append([4, 5])  # Bug is here

assert items == [1, 2, 3, 4, 5]
print("C2 passed ✓")

# %%
# C3: This should remove all even numbers, but it misses some.

nums = [1, 2, 3, 4, 5, 6, 7, 8]
for n in nums:
    if n % 2 == 0:
        nums.remove(n)

assert nums == [1, 3, 5, 7]
print("C3 passed ✓")

# %%
# C4: This function is supposed to return a new list with the item added,
# but callers report weird behavior on repeated calls.

def add_to_list(item, lst=[]):
    lst.append(item)
    return lst

result1 = add_to_list("a")
result2 = add_to_list("b")

assert result1 == ["a"]
assert result2 == ["b"]
print("C4 passed ✓")

# %%
# C5: This creates a 3x3 grid but modifying one row affects all rows.

grid = [[0] * 3] * 3  # Bug is here
grid[0][0] = 1

assert grid == [[1, 0, 0], [0, 0, 0], [0, 0, 0]]
print("C5 passed ✓")

# %%
# C6: This should make a copy, but changes to the copy affect the original.

original = [[1, 2], [3, 4]]
copy = original[:]  # Bug is here (or is it?)
copy[0].append(99)

# Fix so the original is NOT affected
assert original == [[1, 2], [3, 4]]
assert copy == [[1, 2, 99], [3, 4]]
print("C6 passed ✓")

# %% [markdown]
# ---
# ## Section D: Build from Scratch
#
# Write the code yourself to produce the expected result.

# %%
# D1: Without using any built-in functions (no sum, no len),
# calculate the sum of all numbers in the list using a loop.

nums = [4, 7, 2, 9, 1]
# YOUR CODE HERE


assert total == 23
print("D1 passed ✓")

# %%
# D2: Without using .count(), count how many times the value 3 appears.

nums = [1, 3, 5, 3, 7, 3, 9, 3]
# YOUR CODE HERE


assert count == 4
print("D2 passed ✓")

# %%
# D3: Manually reverse a list in-place using swaps (no .reverse(), no [::-1]).
# Hint: two-pointer approach.

nums = [1, 2, 3, 4, 5]
# YOUR CODE HERE


assert nums == [5, 4, 3, 2, 1]
print("D3 passed ✓")

# %%
# D4: Given two sorted lists, merge them into one sorted list.
# Do NOT use sort() or sorted() — use the merge technique.

a = [1, 3, 5, 7]
b = [2, 4, 6, 8]
# YOUR CODE HERE


assert merged == [1, 2, 3, 4, 5, 6, 7, 8]
print("D4 passed ✓")

# %%
# D5: Flatten a 2D list into a 1D list using a loop (no comprehension).

matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# YOUR CODE HERE


assert flat == [1, 2, 3, 4, 5, 6, 7, 8, 9]
print("D5 passed ✓")

# %%
# D6: Build a prefix sum list from nums.
# prefix[i] = sum of nums[0] through nums[i]

nums = [1, 2, 3, 4, 5]
# YOUR CODE HERE


assert prefix == [1, 3, 6, 10, 15]
print("D6 passed ✓")

# %% [markdown]
# ---
# ## Section E: Explore & Discover
#
# Run these cells and observe the behavior. Add comments explaining what you see.

# %%
# E1: What happens when you sort a list of mixed types?
# Try it and see. Then add a comment explaining why.

try:
    mixed = [3, "hello", 1, "world"]
    mixed.sort()
    print(mixed)
except TypeError as e:
    print(f"Error: {e}")
    # YOUR EXPLANATION:

# %%
# E2: What is the id() of a list before and after mutation vs reassignment?

a = [1, 2, 3]
print(f"Original id: {id(a)}")

a.append(4)  # mutation
print(f"After append id: {id(a)}")

a = a + [5]  # reassignment
print(f"After + id: {id(a)}")

# YOUR OBSERVATION: What happened to the id?

# %%
# E3: What does `*` (star) unpacking do in different contexts?

# In assignment
first, *middle, last = [1, 2, 3, 4, 5]
print(f"first={first}, middle={middle}, last={last}")

# With a 2-element list
first, *middle, last = [1, 2]
print(f"first={first}, middle={middle}, last={last}")

# With a 1-element list — what happens?
try:
    first, *middle, last = [1]
except ValueError as e:
    print(f"Error: {e}")

# YOUR OBSERVATION:

# %%
# E4: How does `in` work with nested lists?

nested = [[1, 2], [3, 4], [5, 6]]

print(1 in nested)       # ???
print([1, 2] in nested)  # ???
print([1, 3] in nested)  # ???

# YOUR OBSERVATION: `in` checks top-level elements only
# To check if 1 exists anywhere, you'd need:
print(any(1 in row for row in nested))

# %%
# E5: What happens when you slice-assign with a different size?

lst = [1, 2, 3, 4, 5]
print(f"Before: {lst}")

# Replace 2 elements with 4 elements
lst[1:3] = [20, 30, 40, 50]
print(f"After replacing [1:3] with 4 items: {lst}")

# Replace 3 elements with 0 elements (delete)
lst[1:5] = []
print(f"After replacing [1:5] with []: {lst}")

# Insert without replacing anything
lst[1:1] = [99, 98, 97]
print(f"After inserting at [1:1]: {lst}")

# YOUR OBSERVATION:
