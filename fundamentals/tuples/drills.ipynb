# %% [markdown]
# # Tuples — Drills (Interactive)
#
# **25+ interactive exercises** covering:
#
# | Section | Type | Count |
# |---------|------|-------|
# | A | Predict the Output | 7 |
# | B | Fill in the Blank | 5 |
# | C | Debug the Bug | 5 |
# | D | Build from Scratch | 5 |
# | E | Explore & Discover | 4 |
#
# **Instructions:** Read the code, make your prediction, then run the cell to check.

# %% [markdown]
# ---
# ## Section A: Predict the Output
#
# Read carefully. Tuples have subtle behavior.

# %%
# A1: What does this print?
# YOUR PREDICTION: ???

a = (5)
b = (5,)
print(type(a))
print(type(b))
print(a)
print(b)

# %%
# A2: What does this print?
# YOUR PREDICTION: ???

t = (1, 2, [3, 4])
t[2].append(5)
print(t)

# %%
# A3: What does this print?
# YOUR PREDICTION: ???

first, *rest = (10, 20, 30, 40)
print(first)
print(rest)
print(type(rest))

# %%
# A4: What does this print?
# YOUR PREDICTION: ???

t = (3, 1, 4, 1, 5, 9)
print(t.count(1))
print(t.index(4))
print(sorted(t))
print(type(sorted(t)))

# %%
# A5: What does this print?
# YOUR PREDICTION: ???

a = (1, 2)
b = (3, 4)
c = a + b
d = a * 3
print(c)
print(d)

# %%
# A6: What does this print?
# YOUR PREDICTION: ???

x = 1, 2, 3
print(type(x))

def f():
    return 4, 5

result = f()
print(result)
print(type(result))

# %%
# A7: What does this print?
# YOUR PREDICTION: ???

t1 = (1, 2, 3)
t2 = (1, 2, 4)
t3 = (1, 2)
print(t1 < t2)
print(t3 < t1)
print(t1 == (1, 2, 3))

# %% [markdown]
# ---
# ## Section B: Fill in the Blank
#
# Replace `____` with the correct code.

# %%
# B1: Create a single-element tuple containing the number 42
single = ____

assert type(single) == tuple
assert len(single) == 1
assert single[0] == 42
print("B1 passed ✓")

# %%
# B2: Unpack the tuple into three variables
data = ("Alice", 25, "Engineer")
____, ____, ____ = data

assert name == "Alice"
assert age == 25
assert job == "Engineer"
print("B2 passed ✓")

# %%
# B3: Swap a and b using tuple unpacking (one line)
a = 10
b = 20
____

assert a == 20
assert b == 10
print("B3 passed ✓")

# %%
# B4: Use a tuple as a dictionary key to store a value
grid = {}
position = (3, 7)
grid[____] = "treasure"

assert grid[(3, 7)] == "treasure"
print("B4 passed ✓")

# %%
# B5: Get the first element and capture all others using star unpacking
t = (100, 200, 300, 400, 500)
____, ____ = t

assert first == 100
assert rest == [200, 300, 400, 500]
print("B5 passed ✓")

# %% [markdown]
# ---
# ## Section C: Debug the Bug
#
# Each cell has a bug. Find it and fix it.

# %%
# C1: This should create a single-element tuple, but it doesn't.

single = ("hello")

assert type(single) == tuple
assert len(single) == 1
print("C1 passed ✓")

# %%
# C2: This should modify the tuple element, but crashes.
# Fix it to CREATE A NEW TUPLE with 99 at index 1.

t = (10, 20, 30)
t[1] = 99  # Bug is here

assert t == (10, 99, 30)
print("C2 passed ✓")

# %%
# C3: This should return a sorted tuple, but returns a list.

nums = (5, 3, 1, 4, 2)
result = sorted(nums)  # Bug: returns a list

assert result == (1, 2, 3, 4, 5)
assert type(result) == tuple
print("C3 passed ✓")

# %%
# C4: This should use a tuple as a set element, but crashes.

points = set()
point = (1, [2, 3])   # Bug is here
points.add(point)

print(f"Points: {points}")
print("C4 passed ✓")

# %%
# C5: This accidentally creates a tuple instead of assigning an int.

x = 42,
y = x + 8  # Should be 50

assert y == 50
assert type(y) == int
print("C5 passed ✓")

# %% [markdown]
# ---
# ## Section D: Build from Scratch
#
# Write the code yourself to produce the expected result.

# %%
# D1: Write a function that takes a tuple and returns a new tuple
# with the elements reversed. Do NOT convert to list.

# YOUR CODE HERE


assert reverse_tuple((1, 2, 3)) == (3, 2, 1)
assert reverse_tuple(()) == ()
assert reverse_tuple(("a",)) == ("a",)
print("D1 passed ✓")

# %%
# D2: Write a function that returns the index of the max value in a tuple.
# If there are ties, return the first occurrence.

# YOUR CODE HERE


assert max_index((3, 7, 2, 9, 5)) == 3
assert max_index((10,)) == 0
assert max_index((5, 5, 5)) == 0
print("D2 passed ✓")

# %%
# D3: Write a function that takes a list of (name, score) tuples
# and returns the name of the person with the highest score.
# If there's a tie, return the first one.

# YOUR CODE HERE


assert top_scorer([("Alice", 90), ("Bob", 95), ("Charlie", 88)]) == "Bob"
assert top_scorer([("Alice", 90), ("Bob", 90)]) == "Alice"
assert top_scorer([("Solo", 100)]) == "Solo"
print("D3 passed ✓")

# %%
# D4: Write a function that takes a tuple and returns a tuple
# with duplicates removed, preserving original order.

# YOUR CODE HERE


assert unique_tuple((1, 2, 2, 3, 1, 4)) == (1, 2, 3, 4)
assert unique_tuple(()) == ()
assert unique_tuple((5, 5, 5)) == (5,)
assert unique_tuple(("a", "b", "a")) == ("a", "b")
print("D4 passed ✓")

# %%
# D5: Write a function that zips two tuples into a tuple of tuples.
# zip_tuples((1, 2, 3), ("a", "b", "c")) → ((1, "a"), (2, "b"), (3, "c"))
# Stop at the shorter tuple.

# YOUR CODE HERE


assert zip_tuples((1, 2, 3), ("a", "b", "c")) == ((1, "a"), (2, "b"), (3, "c"))
assert zip_tuples((1, 2), ("a",)) == ((1, "a"),)
assert zip_tuples((), ("a", "b")) == ()
print("D5 passed ✓")

# %% [markdown]
# ---
# ## Section E: Explore & Discover
#
# Run these and observe. Add comments explaining what you see.

# %%
# E1: Memory comparison — tuple vs list
import sys

for n in [10, 100, 1000, 10000]:
    lst = list(range(n))
    tup = tuple(range(n))
    print(f"n={n:>5}: list={sys.getsizeof(lst):>6} bytes, tuple={sys.getsizeof(tup):>6} bytes, diff={sys.getsizeof(lst) - sys.getsizeof(tup):>5}")

# YOUR OBSERVATION:

# %%
# E2: What methods do tuples have vs lists?
tuple_methods = [m for m in dir(()) if not m.startswith('_')]
list_methods = [m for m in dir([]) if not m.startswith('_')]

print(f"Tuple methods ({len(tuple_methods)}): {tuple_methods}")
print(f"List methods ({len(list_methods)}): {list_methods}")
print(f"\nList-only methods: {[m for m in list_methods if m not in tuple_methods]}")

# YOUR OBSERVATION:

# %%
# E3: What happens with the weird += behavior on a list inside a tuple?

t = ([1, 2],)
print(f"Before: {t}")

try:
    t[0] += [3, 4]  # Does this work?
except TypeError as e:
    print(f"Error: {e}")

print(f"After: {t}")
# Did the list change despite the error? Why?

# YOUR EXPLANATION:

# %%
# E4: Can you hash all of these tuples?
tuples_to_test = [
    (1, 2, 3),
    ("a", "b"),
    (1, (2, 3)),
    (1, [2, 3]),
    ((1, 2), (3, 4)),
    (frozenset({1, 2}),),
]

for t in tuples_to_test:
    try:
        h = hash(t)
        print(f"hash({t}) = {h}")
    except TypeError as e:
        print(f"hash({t}) → TypeError: {e}")

# YOUR OBSERVATION: Which ones are hashable and why?
