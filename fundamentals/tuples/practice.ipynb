# %% [markdown]
# # Tuples — Practice Drills
#
# **20 drills** across 5 difficulty levels. Each cell has:
# - A function stub or TODO
# - Inline `assert` tests
# - A ✓ confirmation on success
#
# | Level | Drills | Focus |
# |-------|--------|-------|
# | 1 — Basics | 1-4 | Creation, indexing, slicing |
# | 2 — Core Ops | 5-8 | Packing, unpacking, operators |
# | 3 — Methods & Patterns | 9-12 | count, index, named tuples, dict keys |
# | 4 — Interview Patterns | 13-16 | Sorting tuples, grouping, coordinate problems |
# | 5 — Advanced | 17-20 | Complex unpacking, immutability tricks, state tracking |

# %% [markdown]
# ---
# ## Level 1 — Basics

# %%
# Drill 1: tuple_from_range
# Create a tuple containing integers 1 through n (inclusive).
# tuple_from_range(5) → (1, 2, 3, 4, 5)

def tuple_from_range(n):
    pass

assert tuple_from_range(5) == (1, 2, 3, 4, 5)
assert tuple_from_range(1) == (1,)
assert tuple_from_range(0) == ()
print("Drill 1 passed ✓")

# %%
# Drill 2: first_last
# Return a tuple of (first_element, last_element) from the input tuple.
# first_last((10, 20, 30)) → (10, 30)

def first_last(t):
    pass

assert first_last((10, 20, 30)) == (10, 30)
assert first_last(("a",)) == ("a", "a")
assert first_last((1, 2)) == (1, 2)
print("Drill 2 passed ✓")

# %%
# Drill 3: slice_middle
# Return a tuple containing all elements EXCEPT the first and last.
# slice_middle((1, 2, 3, 4, 5)) → (2, 3, 4)

def slice_middle(t):
    pass

assert slice_middle((1, 2, 3, 4, 5)) == (2, 3, 4)
assert slice_middle((1, 2)) == ()
assert slice_middle((1,)) == ()
assert slice_middle((10, 20, 30)) == (20,)
print("Drill 3 passed ✓")

# %%
# Drill 4: is_tuple
# Return True if the input is a tuple, False otherwise.
# is_tuple((1, 2)) → True
# is_tuple([1, 2]) → False

def is_tuple(x):
    pass

assert is_tuple((1, 2)) == True
assert is_tuple([1, 2]) == False
assert is_tuple("hello") == False
assert is_tuple(()) == True
assert is_tuple((42,)) == True
print("Drill 4 passed ✓")

# %% [markdown]
# ---
# ## Level 2 — Core Operations

# %%
# Drill 5: concat_tuples
# Concatenate a list of tuples into a single tuple.
# concat_tuples([(1, 2), (3,), (4, 5, 6)]) → (1, 2, 3, 4, 5, 6)

def concat_tuples(tuples):
    pass

assert concat_tuples([(1, 2), (3,), (4, 5, 6)]) == (1, 2, 3, 4, 5, 6)
assert concat_tuples([]) == ()
assert concat_tuples([(), ()]) == ()
assert concat_tuples([(1,)]) == (1,)
print("Drill 5 passed ✓")

# %%
# Drill 6: unpack_sum
# The input is a tuple of exactly 3 integers. Unpack them and return their sum.
# Use tuple unpacking, NOT indexing.
# unpack_sum((10, 20, 30)) → 60

def unpack_sum(t):
    pass

assert unpack_sum((10, 20, 30)) == 60
assert unpack_sum((0, 0, 0)) == 0
assert unpack_sum((-1, 1, 0)) == 0
print("Drill 6 passed ✓")

# %%
# Drill 7: rotate_tuple
# Rotate a tuple to the right by k positions.
# rotate_tuple((1, 2, 3, 4, 5), 2) → (4, 5, 1, 2, 3)

def rotate_tuple(t, k):
    pass

assert rotate_tuple((1, 2, 3, 4, 5), 2) == (4, 5, 1, 2, 3)
assert rotate_tuple((1, 2, 3), 0) == (1, 2, 3)
assert rotate_tuple((1, 2, 3), 3) == (1, 2, 3)
assert rotate_tuple((), 5) == ()
print("Drill 7 passed ✓")

# %%
# Drill 8: swap_pair
# Take a tuple of exactly 2 elements and return them swapped.
# swap_pair(("hello", "world")) → ("world", "hello")

def swap_pair(t):
    pass

assert swap_pair(("hello", "world")) == ("world", "hello")
assert swap_pair((1, 2)) == (2, 1)
assert swap_pair((True, False)) == (False, True)
print("Drill 8 passed ✓")

# %% [markdown]
# ---
# ## Level 3 — Methods & Patterns

# %%
# Drill 9: count_element
# Return how many times `val` appears in tuple `t`.
# Use the built-in tuple method.
# count_element((1, 2, 1, 3, 1), 1) → 3

def count_element(t, val):
    pass

assert count_element((1, 2, 1, 3, 1), 1) == 3
assert count_element((1, 2, 3), 5) == 0
assert count_element((), 1) == 0
assert count_element(("a", "b", "a"), "a") == 2
print("Drill 9 passed ✓")

# %%
# Drill 10: safe_index
# Return the index of `val` in tuple `t`.
# If `val` is not found, return -1 (don't let it crash).
# safe_index((10, 20, 30), 20) → 1
# safe_index((10, 20, 30), 99) → -1

def safe_index(t, val):
    pass

assert safe_index((10, 20, 30), 20) == 1
assert safe_index((10, 20, 30), 99) == -1
assert safe_index((), 1) == -1
assert safe_index(("a", "b", "c"), "c") == 2
print("Drill 10 passed ✓")

# %%
# Drill 11: make_point
# Use collections.namedtuple to create a Point with fields x and y.
# Return a Point instance.
# make_point(3, 7) → Point(x=3, y=7)

from collections import namedtuple

def make_point(x, y):
    pass

p = make_point(3, 7)
assert p.x == 3
assert p.y == 7
assert isinstance(p, tuple)
print("Drill 11 passed ✓")

# %%
# Drill 12: tuple_frequency_map
# Use tuples as dict keys: given a list of (x, y) coordinate tuples,
# return a dict mapping each coordinate to its frequency.
# tuple_frequency_map([(1,2), (3,4), (1,2)]) → {(1,2): 2, (3,4): 1}

def tuple_frequency_map(coords):
    pass

assert tuple_frequency_map([(1,2), (3,4), (1,2)]) == {(1,2): 2, (3,4): 1}
assert tuple_frequency_map([]) == {}
assert tuple_frequency_map([(0,0), (0,0), (0,0)]) == {(0,0): 3}
print("Drill 12 passed ✓")

# %% [markdown]
# ---
# ## Level 4 — Interview Patterns

# %%
# Drill 13: sort_by_second
# Given a list of tuples, return a new list sorted by the SECOND element ascending.
# sort_by_second([("c", 3), ("a", 1), ("b", 2)]) → [("a", 1), ("b", 2), ("c", 3)]

def sort_by_second(pairs):
    pass

assert sort_by_second([("c", 3), ("a", 1), ("b", 2)]) == [("a", 1), ("b", 2), ("c", 3)]
assert sort_by_second([]) == []
assert sort_by_second([("x", 5)]) == [("x", 5)]
print("Drill 13 passed ✓")

# %%
# Drill 14: group_by_key
# Given a list of (key, value) tuples, group values by key into a dict.
# group_by_key([("a", 1), ("b", 2), ("a", 3)]) → {"a": [1, 3], "b": [2]}

def group_by_key(pairs):
    pass

assert group_by_key([("a", 1), ("b", 2), ("a", 3)]) == {"a": [1, 3], "b": [2]}
assert group_by_key([]) == {}
assert group_by_key([("x", 10)]) == {"x": [10]}
print("Drill 14 passed ✓")

# %%
# Drill 15: closest_point
# Given a list of (x, y) tuples and an origin (ox, oy),
# return the point closest to the origin (Euclidean distance).
# If tied, return the first one found.
# closest_point([(3, 4), (1, 1), (6, 8)], (0, 0)) → (1, 1)

def closest_point(points, origin):
    pass

assert closest_point([(3, 4), (1, 1), (6, 8)], (0, 0)) == (1, 1)
assert closest_point([(0, 5), (3, 4)], (0, 0)) == (3, 4)
assert closest_point([(1, 1)], (0, 0)) == (1, 1)
print("Drill 15 passed ✓")

# %%
# Drill 16: enumerate_to_tuples
# Return a tuple of (index, element) tuples for the input sequence.
# enumerate_to_tuples("abc") → ((0, "a"), (1, "b"), (2, "c"))

def enumerate_to_tuples(seq):
    pass

assert enumerate_to_tuples("abc") == ((0, "a"), (1, "b"), (2, "c"))
assert enumerate_to_tuples([10, 20]) == ((0, 10), (1, 20))
assert enumerate_to_tuples("") == ()
print("Drill 16 passed ✓")

# %% [markdown]
# ---
# ## Level 5 — Advanced

# %%
# Drill 17: flatten_nested_tuples
# Flatten a nested tuple structure into a single flat tuple.
# flatten_nested_tuples((1, (2, 3), (4, (5, 6)))) → (1, 2, 3, 4, 5, 6)

def flatten_nested_tuples(t):
    pass

assert flatten_nested_tuples((1, (2, 3), (4, (5, 6)))) == (1, 2, 3, 4, 5, 6)
assert flatten_nested_tuples((1, 2, 3)) == (1, 2, 3)
assert flatten_nested_tuples(()) == ()
assert flatten_nested_tuples(((((1,),),),)) == (1,)
print("Drill 17 passed ✓")

# %%
# Drill 18: tuple_replace
# Return a new tuple where ALL occurrences of `old` are replaced with `new`.
# tuple_replace((1, 2, 3, 2, 4), 2, 99) → (1, 99, 3, 99, 4)

def tuple_replace(t, old, new):
    pass

assert tuple_replace((1, 2, 3, 2, 4), 2, 99) == (1, 99, 3, 99, 4)
assert tuple_replace((1, 1, 1), 1, 0) == (0, 0, 0)
assert tuple_replace((1, 2, 3), 5, 99) == (1, 2, 3)
assert tuple_replace((), 1, 2) == ()
print("Drill 18 passed ✓")

# %%
# Drill 19: most_common_tuple
# Given a list of tuples, return the tuple that appears most often.
# If there's a tie, return any one of the most common.
# most_common_tuple([(1,2), (3,4), (1,2), (5,6), (3,4), (1,2)]) → (1, 2)

def most_common_tuple(tuples):
    pass

assert most_common_tuple([(1,2), (3,4), (1,2), (5,6), (3,4), (1,2)]) == (1, 2)
assert most_common_tuple([(0,0)]) == (0, 0)
print("Drill 19 passed ✓")

# %%
# Drill 20: matrix_to_tuples
# Convert a 2D list (list of lists) into a tuple of tuples.
# matrix_to_tuples([[1, 2], [3, 4], [5, 6]]) → ((1, 2), (3, 4), (5, 6))

def matrix_to_tuples(matrix):
    pass

assert matrix_to_tuples([[1, 2], [3, 4], [5, 6]]) == ((1, 2), (3, 4), (5, 6))
assert matrix_to_tuples([]) == ()
assert matrix_to_tuples([[1]]) == ((1,),)
print("Drill 20 passed ✓")
