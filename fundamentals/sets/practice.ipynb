# %% [markdown]
# # Sets — Practice Drills
#
# **20 graded drills across 5 difficulty levels.**
# Each cell has a function stub for you to complete and inline `assert` tests.
# Run the cell to check your answer — you'll see a pass/fail message immediately.
#
# | Level | Difficulty | Focus |
# |-------|-----------|-------|
# | 1 ⭐ | Beginner | Set creation, membership, basic operations |
# | 2 ⭐⭐ | Easy | Methods, operations, simple patterns |
# | 3 ⭐⭐⭐ | Medium | Multi-step transformations, comprehensions |
# | 4 ⭐⭐⭐⭐ | Hard | Interview patterns, algorithmic thinking |
# | 5 ⭐⭐⭐⭐⭐ | Challenge | Optimized solutions, complex set logic |

# %% [markdown]
# ---
# ## Level 1 ⭐ — Basics

# %%
# Drill 1: Create a set from a list, removing duplicates
# Return the set of unique elements

def unique_elements(lst):
    # TODO
    pass

assert unique_elements([1, 2, 3, 2, 1]) == {1, 2, 3}
assert unique_elements([]) == set()
assert unique_elements([5, 5, 5]) == {5}
assert unique_elements([1]) == {1}
print("Drill 1 passed ✓")

# %%
# Drill 2: Check if an element is in the set
# Return True if the target is in the given set, False otherwise

def is_member(s, target):
    # TODO
    pass

assert is_member({1, 2, 3}, 2) == True
assert is_member({1, 2, 3}, 4) == False
assert is_member(set(), 1) == False
assert is_member({"a", "b"}, "a") == True
print("Drill 2 passed ✓")

# %%
# Drill 3: Return the number of unique elements in a list

def count_unique(lst):
    # TODO
    pass

assert count_unique([1, 2, 3, 2, 1]) == 3
assert count_unique([]) == 0
assert count_unique([7, 7, 7, 7]) == 1
assert count_unique([1, 2, 3, 4, 5]) == 5
print("Drill 3 passed ✓")

# %%
# Drill 4: Return the union of two sets

def combine_sets(s1, s2):
    # TODO
    pass

assert combine_sets({1, 2}, {3, 4}) == {1, 2, 3, 4}
assert combine_sets({1, 2}, {2, 3}) == {1, 2, 3}
assert combine_sets(set(), set()) == set()
assert combine_sets({1}, set()) == {1}
print("Drill 4 passed ✓")

# %% [markdown]
# ---
# ## Level 2 ⭐⭐ — Methods & Operations

# %%
# Drill 5: Return elements that are in set a but NOT in set b

def only_in_first(a, b):
    # TODO
    pass

assert only_in_first({1, 2, 3, 4}, {3, 4, 5}) == {1, 2}
assert only_in_first({1, 2}, {1, 2}) == set()
assert only_in_first({1, 2}, set()) == {1, 2}
assert only_in_first(set(), {1, 2}) == set()
print("Drill 5 passed ✓")

# %%
# Drill 6: Check if set a is a subset of set b

def is_subset(a, b):
    # TODO
    pass

assert is_subset({1, 2}, {1, 2, 3, 4}) == True
assert is_subset({1, 2, 3}, {1, 2}) == False
assert is_subset(set(), {1, 2}) == True
assert is_subset({1, 2}, {1, 2}) == True
print("Drill 6 passed ✓")

# %%
# Drill 7: Return elements in either set but NOT in both
# (symmetric difference)

def exclusive_elements(a, b):
    # TODO
    pass

assert exclusive_elements({1, 2, 3}, {2, 3, 4}) == {1, 4}
assert exclusive_elements({1, 2}, {1, 2}) == set()
assert exclusive_elements({1}, {2}) == {1, 2}
assert exclusive_elements(set(), set()) == set()
print("Drill 7 passed ✓")

# %%
# Drill 8: Check if two sets have NO elements in common

def no_overlap(a, b):
    # TODO
    pass

assert no_overlap({1, 2}, {3, 4}) == True
assert no_overlap({1, 2}, {2, 3}) == False
assert no_overlap(set(), {1, 2}) == True
assert no_overlap(set(), set()) == True
print("Drill 8 passed ✓")

# %% [markdown]
# ---
# ## Level 3 ⭐⭐⭐ — Multi-step Transformations

# %%
# Drill 9: Return unique characters in a string (as a sorted list)

def unique_chars(s):
    # TODO — return a sorted list of unique characters
    pass

assert unique_chars("banana") == ['a', 'b', 'n']
assert unique_chars("") == []
assert unique_chars("aaa") == ['a']
assert unique_chars("abc") == ['a', 'b', 'c']
print("Drill 9 passed ✓")

# %%
# Drill 10: Given a list of required fields and a dict,
# return the set of required fields that are MISSING from the dict's keys

def missing_fields(required, data):
    # TODO
    pass

assert missing_fields(["name", "email", "age"], {"name": "Alice", "email": "a@b.c"}) == {"age"}
assert missing_fields(["a", "b"], {"a": 1, "b": 2, "c": 3}) == set()
assert missing_fields(["x"], {}) == {"x"}
assert missing_fields([], {"a": 1}) == set()
print("Drill 10 passed ✓")

# %%
# Drill 11: Return unique file extensions from a list of filenames
# Extensions should be lowercase without the dot

def unique_extensions(filenames):
    # TODO — return a set of extensions
    pass

assert unique_extensions(["app.py", "main.PY", "style.css", "index.html"]) == {"py", "css", "html"}
assert unique_extensions([]) == set()
assert unique_extensions(["a.txt", "b.txt"]) == {"txt"}
assert unique_extensions(["README", "Makefile"]) == {""}
print("Drill 11 passed ✓")

# %%
# Drill 12: Find all elements that appear in ALL of the given lists
# (intersection of multiple lists)

def common_to_all(*lists):
    # TODO — return a set of elements common to all lists
    # Hint: start with the first list's set and intersect with the rest
    pass

assert common_to_all([1, 2, 3], [2, 3, 4], [3, 4, 5]) == {3}
assert common_to_all([1, 2], [3, 4]) == set()
assert common_to_all([1, 2, 3]) == {1, 2, 3}
assert common_to_all([1, 1, 2], [1, 2, 2], [1, 1, 1]) == {1}
print("Drill 12 passed ✓")

# %% [markdown]
# ---
# ## Level 4 ⭐⭐⭐⭐ — Interview Patterns

# %%
# Drill 13: Contains Duplicate
# Return True if any value appears at least twice in the list
# Must be O(n) time using a set

def contains_duplicate(nums):
    # TODO
    pass

assert contains_duplicate([1, 2, 3, 1]) == True
assert contains_duplicate([1, 2, 3, 4]) == False
assert contains_duplicate([]) == False
assert contains_duplicate([1]) == False
assert contains_duplicate([1, 1]) == True
print("Drill 13 passed ✓")

# %%
# Drill 14: Intersection of Two Arrays
# Return a list of unique elements that appear in both arrays
# Order doesn't matter

def intersection(nums1, nums2):
    # TODO — return a sorted list
    pass

assert intersection([1, 2, 2, 1], [2, 2]) == [2]
assert intersection([4, 9, 5], [9, 4, 9, 8, 4]) == [4, 9]
assert intersection([1, 2], [3, 4]) == []
assert intersection([], [1, 2]) == []
print("Drill 14 passed ✓")

# %%
# Drill 15: Two Sum (using a set)
# Return True if any two distinct elements in the list sum to target
# Must be O(n) time

def has_pair_with_sum(nums, target):
    # TODO — use a set to track complements
    pass

assert has_pair_with_sum([2, 7, 11, 15], 9) == True
assert has_pair_with_sum([2, 7, 11, 15], 10) == False
assert has_pair_with_sum([3, 3], 6) == True
assert has_pair_with_sum([1], 2) == False
assert has_pair_with_sum([], 0) == False
print("Drill 15 passed ✓")

# %%
# Drill 16: Find the Duplicate
# Given a list of n+1 integers where each integer is between 1 and n,
# find the one duplicate number

def find_duplicate(nums):
    # TODO — use a set for O(n) time
    pass

assert find_duplicate([1, 3, 4, 2, 2]) == 2
assert find_duplicate([3, 1, 3, 4, 2]) == 3
assert find_duplicate([1, 1]) == 1
assert find_duplicate([2, 2, 2, 2, 2]) == 2
print("Drill 16 passed ✓")

# %%
# Drill 17: Missing Number
# Given a list containing n distinct numbers from 0 to n,
# find the one number missing from the range

def missing_number(nums):
    # TODO — use a set for O(n) time
    pass

assert missing_number([3, 0, 1]) == 2
assert missing_number([0, 1]) == 2
assert missing_number([9, 6, 4, 2, 3, 5, 7, 0, 1]) == 8
assert missing_number([0]) == 1
print("Drill 17 passed ✓")

# %%
# Drill 18: Set Mismatch
# A set of numbers from 1 to n has one number duplicated and one missing.
# Return [duplicate, missing] as a list.

def find_error(nums):
    # TODO — use a set to find both the duplicate and the missing number
    pass

assert find_error([1, 2, 2, 4]) == [2, 3]
assert find_error([1, 1]) == [1, 2]
assert find_error([2, 2]) == [2, 1]
assert find_error([3, 2, 3, 4, 6, 5]) == [3, 1]
print("Drill 18 passed ✓")

# %% [markdown]
# ---
# ## Level 5 ⭐⭐⭐⭐⭐ — Challenge Problems

# %%
# Drill 19: Longest Consecutive Sequence
# Given an unsorted list of integers, find the length of the
# longest consecutive elements sequence.
# Must be O(n) time — no sorting!
#
# Example: [100, 4, 200, 1, 3, 2] → 4 (the sequence 1,2,3,4)
#
# Hint: Use a set. Only start counting from numbers that are
# the BEGINNING of a sequence (n-1 is NOT in the set).

def longest_consecutive(nums):
    # TODO
    pass

assert longest_consecutive([100, 4, 200, 1, 3, 2]) == 4
assert longest_consecutive([0, 3, 7, 2, 5, 8, 4, 6, 0, 1]) == 9
assert longest_consecutive([]) == 0
assert longest_consecutive([1]) == 1
assert longest_consecutive([1, 2, 0, 1]) == 3
print("Drill 19 passed ✓")

# %%
# Drill 20: Longest Substring Without Repeating Characters
# Given a string, find the length of the longest substring
# that contains no repeating characters.
# Use a sliding window with a set.
#
# Example: "abcabcbb" → 3 ("abc")
# Example: "bbbbb" → 1 ("b")
# Example: "pwwkew" → 3 ("wke")

def length_of_longest_substring(s):
    # TODO
    pass

assert length_of_longest_substring("abcabcbb") == 3
assert length_of_longest_substring("bbbbb") == 1
assert length_of_longest_substring("pwwkew") == 3
assert length_of_longest_substring("") == 0
assert length_of_longest_substring("abcdef") == 6
assert length_of_longest_substring(" ") == 1
print("Drill 20 passed ✓")
