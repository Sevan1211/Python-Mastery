# %% [markdown]
# # Functions — Practice Drills
#
# 20 drills across 5 difficulty levels. **You write the entire function from scratch** —
# the function name, parameters, defaults, and body. Only the description and
# assert tests are provided.
#
# Run each cell after writing your function. The asserts will tell you if it's correct.
#
# **Levels:**
# - Level 1: Basic Definitions (Drills 1–4)
# - Level 2: Parameters & Return Values (Drills 5–8)
# - Level 3: Scope, Lambdas & Higher-Order (Drills 9–12)
# - Level 4: Closures & Decorators (Drills 13–16)
# - Level 5: Advanced Patterns (Drills 17–20)

# %% [markdown]
# ---
# ## Level 1: Basic Definitions

# %%
# Drill 1: Write a function called `is_even` that takes a number
# and returns True if it's even, False otherwise.
# Examples: is_even(4) → True, is_even(7) → False

# YOUR CODE HERE


# --- Tests ---
assert is_even(4) == True
assert is_even(7) == False
assert is_even(0) == True
assert is_even(-2) == True
print("Drill 1 passed ✓")
# Out:
# Drill 1 passed ✓

# %%
# Drill 2: Write a function called `clamp` that constrains a value
# between a minimum and maximum bound.
# Examples:
#   clamp(15, 0, 10) → 10
#   clamp(-5, 0, 10) → 0
#   clamp(5, 0, 10)  → 5

# YOUR CODE HERE


# --- Tests ---
assert clamp(15, 0, 10) == 10
assert clamp(-5, 0, 10) == 0
assert clamp(5, 0, 10) == 5
assert clamp(0, 0, 10) == 0
assert clamp(10, 0, 10) == 10
print("Drill 2 passed ✓")
# Out:
# Drill 2 passed ✓

# %%
# Drill 3: Write a function called `greet` that takes a name and an
# optional greeting (default "Hello"). Returns a formatted string.
# Examples:
#   greet("Alice")                  → "Hello, Alice!"
#   greet("Bob", greeting="Hey")    → "Hey, Bob!"
#   greet("World", "Hi")            → "Hi, World!"
# Hint: think about how to define a default parameter.

# YOUR CODE HERE


# --- Tests ---
assert greet("Alice") == "Hello, Alice!"
assert greet("Bob", greeting="Hey") == "Hey, Bob!"
assert greet("World", "Hi") == "Hi, World!"
print("Drill 3 passed ✓")
# Out:
# Drill 3 passed ✓

# %%
# Drill 4: Write a function called `first_last` that takes a list and
# returns the first and last elements as a tuple.
# Return (None, None) for an empty list.
# Examples:
#   first_last([1, 2, 3, 4]) → (1, 4)
#   first_last(["a"])         → ("a", "a")
#   first_last([])            → (None, None)

# YOUR CODE HERE


# --- Tests ---
assert first_last([1, 2, 3, 4]) == (1, 4)
assert first_last(["a"]) == ("a", "a")
assert first_last([]) == (None, None)
assert first_last([10, 20]) == (10, 20)
print("Drill 4 passed ✓")
# Out:
# Drill 4 passed ✓

# %% [markdown]
# ---
# ## Level 2: Parameters & Return Values

# %%
# Drill 5: Write a function called `safe_divide` that divides a by b.
# If b is 0, return None instead of raising an error.
# Examples:
#   safe_divide(10, 2) → 5.0
#   safe_divide(10, 0) → None
#   safe_divide(0, 5)  → 0.0

# YOUR CODE HERE


# --- Tests ---
assert safe_divide(10, 2) == 5.0
assert safe_divide(10, 0) is None
assert safe_divide(0, 5) == 0.0
assert safe_divide(-6, 3) == -2.0
print("Drill 5 passed ✓")
# Out:
# Drill 5 passed ✓

# %%
# Drill 6: Write a function called `build_profile` that takes a required
# name and any number of additional keyword arguments. Returns a dict
# containing {"name": name} merged with all the keyword args.
# Examples:
#   build_profile("Alice", age=30, role="dev")
#       → {"name": "Alice", "age": 30, "role": "dev"}
#   build_profile("Bob") → {"name": "Bob"}
# Hint: look up **kwargs syntax.

# YOUR CODE HERE


# --- Tests ---
assert build_profile("Alice", age=30, role="dev") == {"name": "Alice", "age": 30, "role": "dev"}
assert build_profile("Bob") == {"name": "Bob"}
assert build_profile("Eve", x=1, y=2, z=3) == {"name": "Eve", "x": 1, "y": 2, "z": 3}
print("Drill 6 passed ✓")

# %%
# Drill 7: Write a function called `concat_all` that takes any number of
# positional string arguments and an optional keyword argument `sep`
# (default " "). Returns all strings joined by the separator.
# Examples:
#   concat_all("a", "b", "c")          → "a b c"
#   concat_all("a", "b", sep="-")      → "a-b"
#   concat_all()                        → ""
# Hint: look up *args syntax.

# YOUR CODE HERE


# --- Tests ---
assert concat_all("a", "b", "c") == "a b c"
assert concat_all("a", "b", sep="-") == "a-b"
assert concat_all("hello") == "hello"
assert concat_all() == ""
assert concat_all("x", "y", "z", sep=", ") == "x, y, z"
print("Drill 7 passed ✓")

# %%
# Drill 8: Write a function called `stats` that takes a list of numbers
# and returns a dict with keys "min", "max", and "mean".
# Return None for an empty list.
# Examples:
#   stats([1, 2, 3, 4, 5]) → {"min": 1, "max": 5, "mean": 3.0}
#   stats([])               → None

# YOUR CODE HERE


# --- Tests ---
assert stats([1, 2, 3, 4, 5]) == {"min": 1, "max": 5, "mean": 3.0}
assert stats([10]) == {"min": 10, "max": 10, "mean": 10.0}
assert stats([]) is None
assert stats([-3, 0, 3]) == {"min": -3, "max": 3, "mean": 0.0}
print("Drill 8 passed ✓")

# %% [markdown]
# ---
# ## Level 3: Scope, Lambdas & Higher-Order Functions

# %%
# Drill 9: Write a function called `apply_to_each` that takes a function
# and a list. Returns a NEW list with the function applied to each element.
# Do NOT use map() — write the loop yourself.
# Examples:
#   apply_to_each(str.upper, ["a", "b", "c"]) → ["A", "B", "C"]
#   apply_to_each(lambda x: x * 2, [1, 2, 3]) → [2, 4, 6]

# YOUR CODE HERE


# --- Tests ---
assert apply_to_each(str.upper, ["a", "b", "c"]) == ["A", "B", "C"]
assert apply_to_each(lambda x: x * 2, [1, 2, 3]) == [2, 4, 6]
assert apply_to_each(len, ["hi", "hello", ""]) == [2, 5, 0]
assert apply_to_each(abs, [-1, 2, -3]) == [1, 2, 3]
print("Drill 9 passed ✓")

# %%
# Drill 10: Write a function called `filter_by` that takes a predicate
# function and a list. Returns a NEW list with only elements where
# the predicate returns True.
# Do NOT use filter() — write the loop yourself.
# Examples:
#   filter_by(lambda x: x > 0, [-1, 0, 1, 2]) → [1, 2]
#   filter_by(str.isupper, ["Hi", "HELLO"])    → ["HELLO"]

# YOUR CODE HERE


# --- Tests ---
assert filter_by(lambda x: x > 0, [-1, 0, 1, 2, -3]) == [1, 2]
assert filter_by(str.isupper, ["Hi", "HELLO", "world"]) == ["HELLO"]
assert filter_by(lambda x: x % 2 == 0, [1, 2, 3, 4]) == [2, 4]
assert filter_by(lambda x: True, [1, 2, 3]) == [1, 2, 3]
print("Drill 10 passed ✓")

# %%
# Drill 11: Write a function called `sort_by_key` that takes a list of
# dicts and a key name (string). Returns a NEW list sorted by that key's value.
# Use a lambda as the sort key.
# Example:
#   sort_by_key([{"name": "Bob", "age": 25}, {"name": "Alice", "age": 30}], "name")
#       → [{"name": "Alice", "age": 30}, {"name": "Bob", "age": 25}]

# YOUR CODE HERE


# --- Tests ---
people = [{"name": "Bob", "age": 25}, {"name": "Alice", "age": 30}, {"name": "Eve", "age": 22}]
assert sort_by_key(people, "name") == [{"name": "Alice", "age": 30}, {"name": "Bob", "age": 25}, {"name": "Eve", "age": 22}]
assert sort_by_key(people, "age") == [{"name": "Eve", "age": 22}, {"name": "Bob", "age": 25}, {"name": "Alice", "age": 30}]
assert sort_by_key([], "name") == []
print("Drill 11 passed ✓")

# %%
# Drill 12: Write a function called `reduce_list` that takes a two-argument
# function and a list. Reduces the list to a single value by repeatedly
# applying the function to the accumulator and next element.
# Do NOT use functools.reduce — write the loop yourself.
# Examples:
#   reduce_list(lambda a, b: a + b, [1, 2, 3, 4]) → 10
#   reduce_list(lambda a, b: a * b, [1, 2, 3, 4]) → 24
#   reduce_list(lambda a, b: a + b, [42])          → 42

# YOUR CODE HERE


# --- Tests ---
assert reduce_list(lambda a, b: a + b, [1, 2, 3, 4]) == 10
assert reduce_list(lambda a, b: a * b, [1, 2, 3, 4]) == 24
assert reduce_list(lambda a, b: max(a, b), [3, 1, 4, 1, 5]) == 5
assert reduce_list(lambda a, b: a + b, [42]) == 42
print("Drill 12 passed ✓")

# %% [markdown]
# ---
# ## Level 4: Closures & Decorators

# %%
# Drill 13: Write a function called `make_counter` that returns a function.
# Each call to the returned function returns the next integer starting from 1.
# Optionally accept a `start` value (default 0) — counting begins after start.
# Examples:
#   c = make_counter()
#   c() → 1, c() → 2, c() → 3
#   c2 = make_counter(10)
#   c2() → 11, c2() → 12
# Hint: use a closure with `nonlocal`.

# YOUR CODE HERE


# --- Tests ---
c1 = make_counter()
assert c1() == 1
assert c1() == 2
assert c1() == 3

c2 = make_counter(10)
assert c2() == 11
assert c2() == 12

# c1 and c2 should be independent
assert c1() == 4
print("Drill 13 passed ✓")

# %%
# Drill 14: Write a function called `make_validator` that takes a list of
# predicate functions. Returns a NEW function that accepts a value and
# returns True only if ALL predicates pass for that value.
# Example:
#   is_valid = make_validator([lambda x: x > 0, lambda x: x < 100, lambda x: x % 2 == 0])
#   is_valid(50) → True
#   is_valid(51) → False  (odd)
#   is_valid(-1) → False  (negative)

# YOUR CODE HERE


# --- Tests ---
is_valid = make_validator([lambda x: x > 0, lambda x: x < 100, lambda x: x % 2 == 0])
assert is_valid(50) == True
assert is_valid(51) == False
assert is_valid(-1) == False
assert is_valid(100) == False
assert is_valid(2) == True
print("Drill 14 passed ✓")

# %%
# Drill 15: Write a decorator called `call_count` that adds a `.calls`
# attribute to the decorated function, tracking how many times it's been called.
# The decorator must preserve the original function's __name__.
# Example:
#   @call_count
#   def add(a, b): return a + b
#   add(1, 2) → 3
#   add.calls → 1
# Hint: look up functools.wraps.

import functools

# YOUR CODE HERE


# --- Tests ---
@call_count
def add(a, b):
    return a + b

assert add(1, 2) == 3
assert add(3, 4) == 7
assert add(5, 6) == 11
assert add.calls == 3
assert add.__name__ == "add"
print("Drill 15 passed ✓")

# %%
# Drill 16: Write a decorator FACTORY called `validate_args` that takes
# an expected type. The decorator checks that ALL positional arguments
# match that type. If not, raise TypeError.
# Example:
#   @validate_args(int)
#   def multiply(a, b): return a * b
#   multiply(3, 4)   → 12
#   multiply(3, "4") → raises TypeError
# Hint: this is a decorator factory — a function that returns a decorator.

# YOUR CODE HERE


# --- Tests ---
@validate_args(int)
def multiply(a, b):
    return a * b

assert multiply(3, 4) == 12

try:
    multiply(3, "4")
    assert False, "Should have raised TypeError"
except TypeError:
    pass

@validate_args(str)
def shout(s):
    return s.upper()

assert shout("hello") == "HELLO"
print("Drill 16 passed ✓")

# %% [markdown]
# ---
# ## Level 5: Advanced Patterns

# %%
# Drill 17: Write a decorator called `once` that ensures a function is
# only called once. Subsequent calls return the cached first result
# without re-executing the function.
# Example:
#   @once
#   def initialize(): return 42
#   initialize() → 42 (runs the function)
#   initialize() → 42 (returns cached result, does NOT run again)

import functools

# YOUR CODE HERE


# --- Tests ---
@once
def initialize():
    print("Initializing...")
    return 42

assert initialize() == 42  # Prints "Initializing..."
assert initialize() == 42  # Does NOT print again
assert initialize() == 42
print("Drill 17 passed ✓")

# %%
# Drill 18: Write a function called `pipe` that takes a value and a list
# of functions. Threads the value through each function in order, passing
# each result as input to the next function.
# Examples:
#   pipe(5, [double, add1, str]) → "11"   (5*2=10, 10+1=11, str(11)="11")
#   pipe(10, [])                 → 10      (no functions, return value as-is)

# YOUR CODE HERE


# --- Tests ---
double = lambda x: x * 2
add1 = lambda x: x + 1
to_str = str

assert pipe(5, [double, add1, to_str]) == "11"
assert pipe(3, [double, double]) == 12
assert pipe("hello", [str.upper, len]) == 5
assert pipe(10, []) == 10
print("Drill 18 passed ✓")

# %%
# Drill 19: Write a function called `make_dispatch` that creates a simple
# function dispatch table. It should return an object with:
#   .register(name) — a decorator that registers a function under `name`
#   .call(name, *args) — calls the registered function with the given args
# Example:
#   dispatch = make_dispatch()
#   @dispatch.register("add")
#   def add(a, b): return a + b
#   dispatch.call("add", 2, 3) → 5
# Hint: you can use a class or a closure with inner functions.

# YOUR CODE HERE


# --- Tests ---
dispatch = make_dispatch()

@dispatch.register("add")
def add(a, b):
    return a + b

@dispatch.register("mul")
def mul(a, b):
    return a * b

assert dispatch.call("add", 2, 3) == 5
assert dispatch.call("mul", 2, 3) == 6
print("Drill 19 passed ✓")

# %%
# Drill 20: Write a decorator called `memoize` that caches results based
# on the function's arguments. Must also expose:
#   .cache        — a dict you can inspect
#   .cache_clear() — a method that resets the cache to empty
# Example:
#   @memoize
#   def fib(n):
#       if n < 2: return n
#       return fib(n-1) + fib(n-2)
#   fib(10) → 55 (cached for speed)
#   fib.cache_clear()  # empties the cache

import functools

# YOUR CODE HERE


# --- Tests ---
@memoize
def fib(n):
    if n < 2:
        return n
    return fib(n - 1) + fib(n - 2)

assert fib(10) == 55
assert fib(20) == 6765
assert 10 in str(fib.cache) or len(fib.cache) > 0  # cache has entries

fib.cache_clear()
assert len(fib.cache) == 0

assert fib(5) == 5  # Works after cache clear
print("Drill 20 passed ✓")
