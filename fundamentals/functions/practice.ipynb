# %% [markdown]
# # Functions — Practice Drills
#
# 20 drills across 5 difficulty levels. Each drill has a TODO stub — write your solution
# and run the cell. Assert tests at the bottom of each cell validate your answer.
#
# **Levels:**
# - Level 1: Basic Definitions (Drills 1–4)
# - Level 2: Parameters & Return Values (Drills 5–8)
# - Level 3: Scope, Lambdas & Higher-Order (Drills 9–12)
# - Level 4: Closures & Decorators (Drills 13–16)
# - Level 5: Advanced Patterns (Drills 17–20)

# %% [markdown]
# ---
# ## Level 1: Basic Definitions

# %%
# Drill 1: Write a function `is_even` that returns True if a number is even.

def is_even(n):
    # TODO: your code here
    pass

assert is_even(4) == True
assert is_even(7) == False
assert is_even(0) == True
assert is_even(-2) == True
print("Drill 1 passed ✓")

# %%
# Drill 2: Write a function `clamp` that constrains a value between a min and max.
# clamp(15, 0, 10) → 10
# clamp(-5, 0, 10) → 0
# clamp(5, 0, 10) → 5

def clamp(value, low, high):
    # TODO: your code here
    pass

assert clamp(15, 0, 10) == 10
assert clamp(-5, 0, 10) == 0
assert clamp(5, 0, 10) == 5
assert clamp(0, 0, 10) == 0
assert clamp(10, 0, 10) == 10
print("Drill 2 passed ✓")

# %%
# Drill 3: Write a function `greet` with a default greeting.
# greet("Alice") → "Hello, Alice!"
# greet("Bob", greeting="Hey") → "Hey, Bob!"

def greet(name, greeting="Hello"):
    # TODO: your code here
    pass

assert greet("Alice") == "Hello, Alice!"
assert greet("Bob", greeting="Hey") == "Hey, Bob!"
assert greet("World", "Hi") == "Hi, World!"
print("Drill 3 passed ✓")

# %%
# Drill 4: Write a function `first_last` that returns the first and last
# elements of a list as a tuple. Return (None, None) for empty list.

def first_last(lst):
    # TODO: your code here
    pass

assert first_last([1, 2, 3, 4]) == (1, 4)
assert first_last(["a"]) == ("a", "a")
assert first_last([]) == (None, None)
assert first_last([10, 20]) == (10, 20)
print("Drill 4 passed ✓")

# %% [markdown]
# ---
# ## Level 2: Parameters & Return Values

# %%
# Drill 5: Write `safe_divide` that returns a / b, but returns None if b is 0.

def safe_divide(a, b):
    # TODO: your code here
    pass

assert safe_divide(10, 2) == 5.0
assert safe_divide(10, 0) is None
assert safe_divide(0, 5) == 0.0
assert safe_divide(-6, 3) == -2.0
print("Drill 5 passed ✓")

# %%
# Drill 6: Write `build_profile` that takes a name (required) and
# any number of keyword arguments. Return a dict with {"name": name, ...kwargs}.
# build_profile("Alice", age=30, role="dev") → {"name": "Alice", "age": 30, "role": "dev"}

def build_profile(name, **kwargs):
    # TODO: your code here
    pass

assert build_profile("Alice", age=30, role="dev") == {"name": "Alice", "age": 30, "role": "dev"}
assert build_profile("Bob") == {"name": "Bob"}
assert build_profile("Eve", x=1, y=2, z=3) == {"name": "Eve", "x": 1, "y": 2, "z": 3}
print("Drill 6 passed ✓")

# %%
# Drill 7: Write `concat_all` that takes any number of positional string args
# and an optional keyword argument `sep` (default " ").
# concat_all("a", "b", "c") → "a b c"
# concat_all("a", "b", sep="-") → "a-b"

def concat_all(*args, sep=" "):
    # TODO: your code here
    pass

assert concat_all("a", "b", "c") == "a b c"
assert concat_all("a", "b", sep="-") == "a-b"
assert concat_all("hello") == "hello"
assert concat_all() == ""
assert concat_all("x", "y", "z", sep=", ") == "x, y, z"
print("Drill 7 passed ✓")

# %%
# Drill 8: Write `stats` that returns a dict with min, max, mean of a list.
# stats([1, 2, 3, 4, 5]) → {"min": 1, "max": 5, "mean": 3.0}
# Return None for empty list.

def stats(nums):
    # TODO: your code here
    pass

assert stats([1, 2, 3, 4, 5]) == {"min": 1, "max": 5, "mean": 3.0}
assert stats([10]) == {"min": 10, "max": 10, "mean": 10.0}
assert stats([]) is None
assert stats([-3, 0, 3]) == {"min": -3, "max": 3, "mean": 0.0}
print("Drill 8 passed ✓")

# %% [markdown]
# ---
# ## Level 3: Scope, Lambdas & Higher-Order Functions

# %%
# Drill 9: Write `apply_to_each` that takes a function and a list,
# returns a new list with the function applied to each element.
# Do NOT use map() — write the loop yourself.

def apply_to_each(func, lst):
    # TODO: your code here
    pass

assert apply_to_each(str.upper, ["a", "b", "c"]) == ["A", "B", "C"]
assert apply_to_each(lambda x: x * 2, [1, 2, 3]) == [2, 4, 6]
assert apply_to_each(len, ["hi", "hello", ""]) == [2, 5, 0]
assert apply_to_each(abs, [-1, 2, -3]) == [1, 2, 3]
print("Drill 9 passed ✓")

# %%
# Drill 10: Write `filter_by` that takes a predicate function and a list,
# returns a new list with only elements where predicate returns True.
# Do NOT use filter() — write the loop yourself.

def filter_by(predicate, lst):
    # TODO: your code here
    pass

assert filter_by(lambda x: x > 0, [-1, 0, 1, 2, -3]) == [1, 2]
assert filter_by(str.isupper, ["Hi", "HELLO", "world"]) == ["HELLO"]
assert filter_by(lambda x: x % 2 == 0, [1, 2, 3, 4]) == [2, 4]
assert filter_by(lambda x: True, [1, 2, 3]) == [1, 2, 3]
print("Drill 10 passed ✓")

# %%
# Drill 11: Write `sort_by_key` that sorts a list of dicts by a given key.
# Use a lambda as the sort key.
# sort_by_key([{"name": "Bob", "age": 25}, {"name": "Alice", "age": 30}], "name")
# → [{"name": "Alice", "age": 30}, {"name": "Bob", "age": 25}]

def sort_by_key(dicts, key):
    # TODO: your code here
    pass

people = [{"name": "Bob", "age": 25}, {"name": "Alice", "age": 30}, {"name": "Eve", "age": 22}]
assert sort_by_key(people, "name") == [{"name": "Alice", "age": 30}, {"name": "Bob", "age": 25}, {"name": "Eve", "age": 22}]
assert sort_by_key(people, "age") == [{"name": "Eve", "age": 22}, {"name": "Bob", "age": 25}, {"name": "Alice", "age": 30}]
assert sort_by_key([], "name") == []
print("Drill 11 passed ✓")

# %%
# Drill 12: Write `reduce_list` that takes a function and a list,
# and reduces it to a single value (like functools.reduce).
# Do NOT use functools.reduce — write the loop yourself.
# reduce_list(lambda a, b: a + b, [1, 2, 3, 4]) → 10
# reduce_list(lambda a, b: a * b, [1, 2, 3, 4]) → 24

def reduce_list(func, lst):
    # TODO: your code here
    pass

assert reduce_list(lambda a, b: a + b, [1, 2, 3, 4]) == 10
assert reduce_list(lambda a, b: a * b, [1, 2, 3, 4]) == 24
assert reduce_list(lambda a, b: max(a, b), [3, 1, 4, 1, 5]) == 5
assert reduce_list(lambda a, b: a + b, [42]) == 42
print("Drill 12 passed ✓")

# %% [markdown]
# ---
# ## Level 4: Closures & Decorators

# %%
# Drill 13: Write `make_counter` that returns a function. Each time
# the returned function is called, it returns the next integer.
# c = make_counter()
# c() → 1, c() → 2, c() → 3
# Optionally accept a start value: make_counter(10) → 11, 12, 13...

def make_counter(start=0):
    # TODO: your code here (use closure with nonlocal)
    pass

c1 = make_counter()
assert c1() == 1
assert c1() == 2
assert c1() == 3

c2 = make_counter(10)
assert c2() == 11
assert c2() == 12

# c1 and c2 should be independent
assert c1() == 4
print("Drill 13 passed ✓")

# %%
# Drill 14: Write `make_validator` that takes a list of predicate functions.
# Returns a function that returns True only if ALL predicates pass.
# is_valid = make_validator([lambda x: x > 0, lambda x: x < 100, lambda x: x % 2 == 0])
# is_valid(50) → True, is_valid(51) → False (odd), is_valid(-1) → False

def make_validator(predicates):
    # TODO: your code here
    pass

is_valid = make_validator([lambda x: x > 0, lambda x: x < 100, lambda x: x % 2 == 0])
assert is_valid(50) == True
assert is_valid(51) == False
assert is_valid(-1) == False
assert is_valid(100) == False
assert is_valid(2) == True
print("Drill 14 passed ✓")

# %%
# Drill 15: Write a `call_count` decorator that adds a `.calls` attribute
# to the function tracking how many times it's been called.
# Remember @functools.wraps.

import functools

def call_count(func):
    # TODO: your code here
    pass

@call_count
def add(a, b):
    return a + b

assert add(1, 2) == 3
assert add(3, 4) == 7
assert add(5, 6) == 11
assert add.calls == 3
assert add.__name__ == "add"
print("Drill 15 passed ✓")

# %%
# Drill 16: Write a `validate_args` decorator that checks all positional args
# are of a given type. If not, raise TypeError.
# @validate_args(int)
# def add(a, b): return a + b
# add(1, 2) → 3
# add(1, "2") → TypeError

def validate_args(expected_type):
    # TODO: your code here (decorator factory)
    pass

@validate_args(int)
def multiply(a, b):
    return a * b

assert multiply(3, 4) == 12

try:
    multiply(3, "4")
    assert False, "Should have raised TypeError"
except TypeError:
    pass

@validate_args(str)
def shout(s):
    return s.upper()

assert shout("hello") == "HELLO"
print("Drill 16 passed ✓")

# %% [markdown]
# ---
# ## Level 5: Advanced Patterns

# %%
# Drill 17: Write `once` — a decorator that ensures a function is only
# called once. Subsequent calls return the cached first result.

import functools

def once(func):
    # TODO: your code here
    pass

@once
def initialize():
    print("Initializing...")
    return 42

assert initialize() == 42  # Prints "Initializing..."
assert initialize() == 42  # Does NOT print again
assert initialize() == 42
print("Drill 17 passed ✓")

# %%
# Drill 18: Write `pipe` that takes a value and a list of functions,
# and threads the value through each function in order.
# pipe(5, [double, add1, str]) → "11"

def pipe(value, functions):
    # TODO: your code here
    pass

double = lambda x: x * 2
add1 = lambda x: x + 1
to_str = str

assert pipe(5, [double, add1, to_str]) == "11"
assert pipe(3, [double, double]) == 12
assert pipe("hello", [str.upper, len]) == 5
assert pipe(10, []) == 10
print("Drill 18 passed ✓")

# %%
# Drill 19: Write `dispatch` — a simple function dispatch table.
# dispatch = make_dispatch()
# @dispatch.register("add")
# def add(a, b): return a + b
# @dispatch.register("mul")
# def mul(a, b): return a * b
# dispatch.call("add", 2, 3) → 5
# dispatch.call("mul", 2, 3) → 6

def make_dispatch():
    # TODO: your code here
    # Hint: return an object or namespace with .register and .call methods
    # You can use a class or a closure with inner functions
    pass

dispatch = make_dispatch()

@dispatch.register("add")
def add(a, b):
    return a + b

@dispatch.register("mul")
def mul(a, b):
    return a * b

assert dispatch.call("add", 2, 3) == 5
assert dispatch.call("mul", 2, 3) == 6
print("Drill 19 passed ✓")

# %%
# Drill 20: Write `memoize` — a decorator that caches results based on args.
# Must also expose a `.cache` attribute so you can inspect it,
# and a `.cache_clear()` method to reset the cache.

import functools

def memoize(func):
    # TODO: your code here
    pass

@memoize
def fib(n):
    if n < 2:
        return n
    return fib(n - 1) + fib(n - 2)

assert fib(10) == 55
assert fib(20) == 6765
assert 10 in str(fib.cache) or len(fib.cache) > 0  # cache has entries

fib.cache_clear()
assert len(fib.cache) == 0

assert fib(5) == 5  # Works after cache clear
print("Drill 20 passed ✓")
